# %%
#Import pandas, matplotlib.pyplot, and seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
# %matplotlib inline

from matplotlib import colors as mcolors

pd.set_option('display.max_columns', None)

# %%
#This is for multiple output on Jupyter Notebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
def outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    return outliers

# %%
def color_picker(color_list):
    """ Picks a random color from color index """
    pass
    return random.choice(color_list)

# %% [markdown]
# 1. Load and Check Data

# %%
df = pd.read_csv("C:/Users/umitk/OneDrive/Documents/myspringboard/house prediction/train.csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam     2Story            7            5       2003
# 1          Norm     1Fam     1Story            6            8       1976
# 2          Norm     1Fam     2Story            7            5       2001
# 3          Norm     1Fam     2Story            7            5       1915
# 4          Norm     1Fam     2Story            8            5       2000
# ...         ...      ...        ...          ...          ...        ...
# 1455       Norm     1Fam     2Story            6            5       1999
# 1456       Norm     1Fam     1Story            6            6       1978
# 1457       Norm     1Fam     2Story            7            9       1941
# 1458       Norm     1Fam     1Story            5            6       1950
# 1459       Norm     1Fam     1Story            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2             2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3             1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 1455          2000     Gable  CompShg     VinylSd     VinylSd        NaN
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd        NaN
# 1458          1996       Hip  CompShg     MetalSd     MetalSd        NaN
# 1459          1965     Gable  CompShg     HdBoard     HdBoard        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# 2          162.0        Gd        TA      PConc       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 4          350.0        Gd        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         NaN     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 4                9        Typ           1          TA     Attchd       2000.0
# ...            ...        ...         ...         ...        ...          ...
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0         NaN     Attchd       1950.0
# 1459             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN    NaN         NaN        0       2    2008       WD
# 1            0    NaN    NaN         NaN        0       5    2007       WD
# 2            0    NaN    NaN         NaN        0       9    2008       WD
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1455         0    NaN    NaN         NaN        0       8    2007       WD
# 1456         0    NaN  MnPrv         NaN        0       2    2010       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1458         0    NaN    NaN         NaN        0       4    2010       WD
# 1459         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice
# 0           Normal     208500
# 1           Normal     181500
# 2           Normal     223500
# 3          Abnorml     140000
# 4           Normal     250000
# ...            ...        ...
# 1455        Normal     175000
# 1456        Normal     210000
# 1457        Normal     266500
# 1458        Normal     142125
# 1459        Normal     147500
#
# [1460 rows x 81 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466
# std     161.319273   441.866955   438.705324   386.587738   436.528436
# min       0.000000     0.000000     0.000000   334.000000     0.000000
# 25%       0.000000   223.000000   795.750000   882.000000     0.000000
# 50%       0.000000   477.500000   991.500000  1087.000000     0.000000
# 75%       0.000000   808.000000  1298.250000  1391.250000   728.000000
# max    1474.000000  2336.000000  6110.000000  4692.000000  2065.000000
#
#        LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath  \
# count   1460.000000  1460.000000   1460.000000   1460.000000  1460.000000
# mean       5.844521  1515.463699      0.425342      0.057534     1.565068
# std       48.623081   525.480383      0.518911      0.238753     0.550916
# min        0.000000   334.000000      0.000000      0.000000     0.000000
# 25%        0.000000  1129.500000      0.000000      0.000000     1.000000
# 50%        0.000000  1464.000000      0.000000      0.000000     2.000000
# 75%        0.000000  1776.750000      1.000000      0.000000     2.000000
# max      572.000000  5642.000000      3.000000      2.000000     3.000000
#
#           HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000   1460.000000   1460.000000   1460.000000  1460.000000
# mean      0.382877      2.866438      1.046575      6.517808     0.613014
# std       0.502885      0.815778      0.220338      1.625393     0.644666
# min       0.000000      0.000000      0.000000      2.000000     0.000000
# 25%       0.000000      2.000000      1.000000      5.000000     0.000000
# 50%       0.000000      3.000000      1.000000      6.000000     1.000000
# 75%       1.000000      3.000000      1.000000      7.000000     1.000000
# max       2.000000      8.000000      3.000000     14.000000     3.000000
#
#        GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1379.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1978.506164     1.767123   472.980137    94.244521    46.660274
# std      24.689725     0.747315   213.804841   125.338794    66.256028
# min    1900.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1961.000000     1.000000   334.500000     0.000000     0.000000
# 50%    1980.000000     2.000000   480.000000     0.000000    25.000000
# 75%    2002.000000     2.000000   576.000000   168.000000    68.000000
# max    2010.000000     4.000000  1418.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
#             MoSold       YrSold      SalePrice
# count  1460.000000  1460.000000    1460.000000
# mean      6.321918  2007.815753  180921.195890
# std       2.703626     1.328095   79442.502883
# min       1.000000  2006.000000   34900.000000
# 25%       5.000000  2007.000000  129975.000000
# 50%       6.000000  2008.000000  163000.000000
# 75%       8.000000  2009.000000  214000.000000
# max      12.000000  2010.000000  755000.000000

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df.shape
# Out:
# (1460, 81)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
# Numerical Columns
numerical_columns = df.select_dtypes(include = ['float64', 'int64']).columns
numerical_columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
categorical_columns = df.select_dtypes(include = ['object']).columns
categorical_columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
len(categorical_columns)
# Out:
# 43

# %%
missing_values = df.isnull().sum()
missing_values[missing_values > 0].sort_values(ascending = False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
num_missing_values = df[numerical_columns].isnull().sum()
#num_missing_values[num_missing_values > 0].sort_values(ascending = False)

# %%
num_missing_values
num_missing_values[num_missing_values > 0].sort_values(ascending = False)
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64
# LotFrontage    259
# GarageYrBlt     81
# MasVnrArea       8
# dtype: int64

# %%
cat_missing_values = df[categorical_columns].isnull().sum()
cat_missing_values[cat_missing_values > 0 ].sort_values(ascending = False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# Electrical         1
# dtype: int64

# %% [raw]
# 2. Handling Missing Values
# 2.1. Handling Missing Values in Categorical Features
# PoolQC: Pool quality
# In blow step, the "PoolQC" column was examined, revealing that only 7 dwellings have a pool. Given this limited data and the fact that this variable would only be relevant for those specific cases, it seems appropriate to consider dropping this column. Instead, the "PoolArea" column can be utilized to identify which houses have a pool, as it provides more comprehensive information in this regard.

# %%
df.loc[~df['PoolQC'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197    198          75       RL        174.0    25419   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1170  1171          80       RL         76.0     9880   Pave   NaN      Reg
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1386  1387          60       RL         80.0    16692   Pave   NaN      IR1
# 1423  1424          80       RL          NaN    19690   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 197          Lvl    AllPub    Corner       Gtl        NAmes     Artery
# 810          Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1170         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1182         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
# 1386         Lvl    AllPub    Inside       Gtl       NWAmes       RRAn
# 1423         Lvl    AllPub   CulDSac       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 197        Norm     1Fam     2Story            8            4       1918
# 810        Norm     1Fam     1Story            6            6       1974
# 1170       Norm     1Fam       SLvl            6            6       1977
# 1182       Norm     1Fam     2Story           10            5       1996
# 1298       Norm     1Fam     2Story           10            5       2008
# 1386       Norm     1Fam     2Story            7            5       1978
# 1423       Norm     1Fam       SLvl            6            7       1966
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 197           1990     Gable  CompShg      Stucco      Stucco        NaN
# 810           1999       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1170          1977     Gable  CompShg     Plywood     Plywood        NaN
# 1182          1996       Hip  CompShg     Wd Sdng     ImStucc        NaN
# 1298          2008       Hip  ClyTile      Stucco      Stucco      Stone
# 1386          1978     Gable  CompShg     Plywood     Plywood    BrkFace
# 1423          1966      Flat  Tar&Grv     Plywood     Plywood        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 197          0.0        Gd        Gd      PConc       TA       TA
# 810         99.0        TA        TA     CBlock       TA       TA
# 1170         0.0        TA        TA     CBlock       TA       TA
# 1182         0.0        Gd        TA      PConc       Ex       TA
# 1298       796.0        Ex        TA      PConc       Ex       TA
# 1386       184.0        TA        TA     CBlock       Gd       TA
# 1423         0.0        Gd        Gd     CBlock       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 197            No          GLQ        1036          LwQ         184
# 810            No          ALQ         663          LwQ         377
# 1170           Av          ALQ         522          Unf           0
# 1182           Av          GLQ        2096          Unf           0
# 1298           Gd          GLQ        5644          Unf           0
# 1386           No          BLQ         790          LwQ         469
# 1423           Av          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 197         140         1360    GasA        Gd          Y      SBrkr
# 810           0         1040    GasA        Fa          Y      SBrkr
# 1170        574         1096    GasA        TA          Y      SBrkr
# 1182        300         2396    GasA        Ex          Y      SBrkr
# 1298        466         6110    GasA        Ex          Y      SBrkr
# 1386        133         1392    GasA        TA          Y      SBrkr
# 1423        697          697    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 197       1360      1360           392       3112             1             1
# 810       1309         0             0       1309             1             0
# 1170      1118         0             0       1118             1             0
# 1182      2411      2065             0       4476             1             0
# 1298      4692       950             0       5642             2             0
# 1386      1392      1392             0       2784             1             0
# 1423      1575       626             0       2201             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 197          2         0             4             1          Gd
# 810          1         1             3             1          Gd
# 1170         1         0             3             1          TA
# 1182         3         1             4             1          Ex
# 1298         2         1             3             1          Ex
# 1386         3         1             5             1          Gd
# 1423         2         0             4             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 197              8        Typ           1          Ex     Detchd       1918.0
# 810              5        Typ           1          Fa     Attchd       1974.0
# 1170             6        Typ           1          Po     Attchd       1977.0
# 1182            10        Typ           2          TA     Attchd       1996.0
# 1298            12        Typ           3          Gd     Attchd       2008.0
# 1386            12        Typ           2          TA     Attchd       1978.0
# 1423             8        Typ           1          Gd     Attchd       1966.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 197           Unf           2         795         TA         TA          Y
# 810           RFn           2         484         TA         TA          Y
# 1170          Fin           1         358         TA         TA          Y
# 1182          Fin           3         813         TA         TA          Y
# 1298          Fin           2        1418         TA         TA          Y
# 1386          RFn           2         564         TA         TA          Y
# 1423          Unf           2         432         Gd         Gd          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 197            0           16            552          0            0
# 810          265            0              0          0            0
# 1170         203            0              0          0            0
# 1182         171           78              0          0            0
# 1298         214          292              0          0            0
# 1386           0          112              0          0          440
# 1423         586          236              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 197        512     Ex  GdPrv         NaN        0       3    2006       WD
# 810        648     Fa  GdPrv         NaN        0       1    2006       WD
# 1170       576     Gd  GdPrv         NaN        0       7    2008       WD
# 1182       555     Ex  MnPrv         NaN        0       7    2007       WD
# 1298       480     Gd    NaN         NaN        0       1    2008      New
# 1386       519     Fa  MnPrv        TenC     2000       7    2006       WD
# 1423       738     Gd  GdPrv         NaN        0       8    2006       WD
#
#      SaleCondition  SalePrice
# 197        Abnorml     235000
# 810         Normal     181000
# 1170        Normal     171000
# 1182       Abnorml     745000
# 1298       Partial     160000
# 1386        Normal     250000
# 1423        Alloca     274970

# %%
df['PoolQC'].value_counts()
# Out:
# PoolQC
# Gd    3
# Ex    2
# Fa    2
# Name: count, dtype: int64

# %%
if 'PoolQC' in df.columns:
    pass
    df.drop(columns = 'PoolQC', inplace = True)
df.head()
print('Number of columns: ' + str(len(df.columns)))
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0         0   NaN         NaN        0       2    2008       WD
# 1            0         0   NaN         NaN        0       5    2007       WD
# 2            0         0   NaN         NaN        0       9    2008       WD
# 3            0         0   NaN         NaN        0       2    2006       WD
# 4            0         0   NaN         NaN        0      12    2008       WD
#
#   SaleCondition  SalePrice
# 0        Normal     208500
# 1        Normal     181500
# 2        Normal     223500
# 3       Abnorml     140000
# 4        Normal     250000
# Number of columns: 80

# %% [markdown]
# MiscFeature: Miscellaneous feature not covered in other categories
#
# In below step, an assessment of the "MiscFeatures" column revealed that only 54 dwellings possess these features. Given this limited representation and the potential challenges associated with imputing null values for such a small subset, it seems reasonable to consider dropping this column from the dataset.

# %%
df.loc[~df['MiscFeature'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# 51      52          50       RM         52.0     6240   Pave   NaN      Reg
# 84      85          80       RL          NaN     8530   Pave   NaN      IR1
# 95      96          60       RL          NaN     9765   Pave   NaN      IR2
# 98      99          30       RL         85.0    10625   Pave   NaN      Reg
# 99     100          20       RL         77.0     9320   Pave   NaN      IR1
# 106    107          30       RM         60.0    10800   Pave  Grvl      Reg
# 214    215          60       RL          NaN    10900   Pave   NaN      IR1
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 250    251          30       RL         55.0     5350   Pave   NaN      IR1
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 338    339          20       RL         91.0    14145   Pave   NaN      Reg
# 346    347          20       RL          NaN    12772   Pave   NaN      IR1
# 392    393          20       RL          NaN     8339   Pave   NaN      IR1
# 439    440          50       RL         67.0    12354   Pave  Grvl      Reg
# 499    500          20       RL         70.0     7535   Pave   NaN      IR1
# 502    503          20       RL         70.0     9170   Pave   NaN      Reg
# 510    511          20       RL         75.0    14559   Pave   NaN      Reg
# 539    540          20       RL          NaN    11423   Pave   NaN      Reg
# 589    590          40       RM         50.0     9100   Pave   NaN      Reg
# 611    612          80       RL          NaN    10395   Pave   NaN      IR1
# 626    627          20       RL          NaN    12342   Pave   NaN      IR1
# 634    635          90       RL         64.0     6979   Pave   NaN      Reg
# 705    706         190       RM         70.0     5600   Pave   NaN      Reg
# 725    726          20       RL         60.0     6960   Pave   NaN      Reg
# 733    734          20       RL         80.0    10000   Pave   NaN      Reg
# 760    761          20       RL         70.0     9100   Pave   NaN      Reg
# 766    767          60       RL         80.0    10421   Pave   NaN      Reg
# 767    768          50       RL         75.0    12508   Pave   NaN      IR1
# 786    787          50       RM         60.0    10800   Pave   NaN      Reg
# 794    795          60       RL          NaN    10832   Pave   NaN      IR1
# 800    801          60       RL         79.0    12798   Pave   NaN      IR1
# 812    813          20  C (all)         66.0     8712   Grvl   NaN      Reg
# 813    814          20       RL         75.0     9750   Pave   NaN      Reg
# 867    868          20       RL         85.0     6970   Pave   NaN      Reg
# 873    874          40       RL         60.0    12144   Pave   NaN      Reg
# 878    879          85       RL         88.0    11782   Pave   NaN      IR1
# 890    891          50       RL         60.0     8064   Pave   NaN      Reg
# 912    913          30       RM         51.0     6120   Pave   NaN      Reg
# 953    954          60       RL          NaN    11075   Pave   NaN      IR1
# 1061  1062          30  C (all)        120.0    18000   Grvl   NaN      Reg
# 1076  1077          50       RL         60.0    10800   Pave  Grvl      Reg
# 1083  1084          20       RL         80.0     8800   Pave   NaN      Reg
# 1171  1172          20       RL         76.0     9120   Pave   NaN      Reg
# 1200  1201          20       RL         71.0     9353   Pave   NaN      Reg
# 1210  1211          60       RL         70.0    11218   Pave   NaN      Reg
# 1230  1231          90       RL          NaN    18890   Pave   NaN      IR1
# 1252  1253          20       RL         62.0     9858   Pave   NaN      Reg
# 1328  1329          50       RM         60.0    10440   Pave  Grvl      Reg
# 1386  1387          60       RL         80.0    16692   Pave   NaN      IR1
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 5            Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 7            Lvl    AllPub    Corner       Gtl       NWAmes       PosN
# 16           Lvl    AllPub   CulDSac       Gtl        NAmes       Norm
# 17           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 51           Lvl    AllPub    Inside       Gtl      BrkSide       Norm
# 84           Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 95           Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 98           Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 99           Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 106          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 214          Lvl    AllPub       FR2       Gtl      CollgCr       Norm
# 249          Low    AllPub   CulDSac       Sev      ClearCr       Norm
# 250          Lvl    AllPub    Inside       Gtl      BrkSide       Norm
# 335          HLS    AllPub    Corner       Sev       Timber       Norm
# 338          Lvl    AllPub    Corner       Gtl       NWAmes       Norm
# 346          Lvl    AllPub   CulDSac       Gtl        NAmes       Norm
# 392          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 439          Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 499          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 502          Lvl    AllPub    Corner       Gtl      Edwards      Feedr
# 510          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 539          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 589          Lvl    AllPub    Inside       Gtl      BrkSide       RRAn
# 611          Lvl    AllPub       FR2       Gtl       NWAmes       Norm
# 626          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 634          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 705          Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 725          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 733          Lvl    AllPub    Corner       Gtl       Sawyer      Feedr
# 760          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 766          Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 767          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 786          Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 794          Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 800          HLS    AllPub    Inside       Mod      ClearCr      Feedr
# 812          Bnk    AllPub    Inside       Mod       IDOTRR       Norm
# 813          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 867          Lvl    AllPub    Corner       Gtl       Sawyer      Feedr
# 873          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 878          Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 890          Lvl    AllPub    Corner       Gtl        NAmes     Artery
# 912          Lvl    AllPub    Inside       Gtl      BrkSide       Norm
# 953          Lvl    AllPub    Inside       Mod      Mitchel       Norm
# 1061         Low    AllPub    Inside       Gtl       IDOTRR       Norm
# 1076         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1083         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1171         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1200         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1210         Lvl    AllPub    Inside       Gtl      SawyerW       Norm
# 1230         Lvl    AllPub    Inside       Gtl       Sawyer      Feedr
# 1252         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1328         Lvl    AllPub    Corner       Gtl      OldTown       Norm
# 1386         Lvl    AllPub    Inside       Gtl       NWAmes       RRAn
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 5          Norm     1Fam     1.5Fin            5            5       1993
# 7          Norm     1Fam     2Story            7            6       1973
# 16         Norm     1Fam     1Story            6            7       1970
# 17         Norm   Duplex     1Story            4            5       1967
# 51         Norm     1Fam     1.5Fin            6            6       1934
# 84         Norm     1Fam       SLvl            7            5       1995
# 95         Norm     1Fam     2Story            6            8       1993
# 98         Norm     1Fam     1Story            5            5       1920
# 99         Norm     1Fam     1Story            4            5       1959
# 106        Norm     1Fam     1Story            4            7       1885
# 214        Norm     1Fam     2Story            6            7       1977
# 249        Norm     1Fam     1.5Fin            6            7       1958
# 250        Norm     1Fam     1Story            3            2       1940
# 335        Norm   2fmCon     1.5Fin            5            6       1965
# 338        Norm     1Fam     1Story            7            7       1984
# 346        Norm     1Fam     1Story            6            8       1960
# 392        Norm     1Fam     1Story            5            7       1959
# 439        Norm     1Fam     1.5Fin            6            8       1920
# 499        Norm     1Fam     1Story            5            7       1958
# 502        Norm     1Fam     1Story            5            7       1965
# 510        Norm     1Fam     1Story            5            7       1951
# 539        Norm     1Fam     1Story            8            5       2001
# 589       Feedr     1Fam     1Story            5            6       1930
# 611        Norm     1Fam       SLvl            6            6       1978
# 626        Norm     1Fam     1Story            5            5       1960
# 634        Norm   Duplex     SFoyer            6            5       1980
# 705        Norm   2fmCon     2Story            4            5       1930
# 725        Norm     1Fam     1Story            4            6       1970
# 733        Norm     1Fam     1Story            5            6       1961
# 760        Norm     1Fam     1Story            6            6       1959
# 766        Norm     1Fam     2Story            7            5       1988
# 767        Norm     1Fam     1.5Fin            6            7       1940
# 786        Norm     1Fam     1.5Fin            5            6       1915
# 794        Norm     1Fam     2Story            7            5       1994
# 800        Norm     1Fam     2Story            6            5       1997
# 812        Norm     1Fam     1Story            5            5       1952
# 813        Norm     1Fam     1Story            6            6       1958
# 867        Norm     1Fam     1Story            4            5       1961
# 873        Norm     1Fam     1Story            5            7       1949
# 878        Norm     1Fam     SFoyer            5            7       1961
# 890        Norm     1Fam     1.5Fin            5            7       1949
# 912        Norm     1Fam     1Story            5            7       1925
# 953        Norm     1Fam     2Story            5            4       1969
# 1061       Norm     1Fam     1Story            3            4       1935
# 1076       Norm     1Fam     1.5Fin            5            8       1936
# 1083       Norm     1Fam     1Story            6            6       1964
# 1171       Norm     1Fam     1Story            6            6       1958
# 1200       Norm     1Fam     1Story            4            5       1970
# 1210       Norm     1Fam     2Story            6            5       1992
# 1230       RRAe   Duplex     1.5Fin            5            5       1977
# 1252       Norm     1Fam     1Story            5            6       1968
# 1328       Norm     1Fam     1.5Fin            6            7       1920
# 1386       Norm     1Fam     2Story            7            5       1978
# 1457       Norm     1Fam     2Story            7            9       1941
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 5             1995     Gable  CompShg     VinylSd     VinylSd        NaN
# 7             1973     Gable  CompShg     HdBoard     HdBoard      Stone
# 16            1970     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 17            1967     Gable  CompShg     MetalSd     MetalSd        NaN
# 51            1950     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 84            1996     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 95            1993     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 98            1950     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 99            1959     Gable  CompShg     Plywood     Plywood        NaN
# 106           1995   Mansard  CompShg     VinylSd     VinylSd        NaN
# 214           1977     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 249           2006     Gable  CompShg     Wd Sdng     HdBoard     BrkCmn
# 250           1966     Gable  CompShg     Wd Sdng     Plywood        NaN
# 335           1965     Gable  CompShg     Plywood     Plywood        NaN
# 338           1998     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 346           1998       Hip  CompShg     MetalSd     MetalSd        NaN
# 392           1959     Gable  CompShg     MetalSd     MetalSd        NaN
# 439           2000     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 499           1985     Gable  CompShg     MetalSd     MetalSd        NaN
# 502           1965       Hip  CompShg     MetalSd     MetalSd        NaN
# 510           2000       Hip  CompShg     Wd Sdng     Wd Sdng     BrkCmn
# 539           2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 589           1960     Gable  CompShg     VinylSd     VinylSd        NaN
# 611           1978     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 626           1978       Hip  CompShg     Wd Sdng     Wd Sdng        NaN
# 634           1980     Gable  CompShg     Plywood     Plywood        NaN
# 705           1950       Hip  CompShg     VinylSd     Wd Shng        NaN
# 725           1970     Gable  CompShg     HdBoard     Plywood        NaN
# 733           1983       Hip  CompShg     HdBoard     HdBoard        NaN
# 760           1959       Hip  CompShg     Wd Sdng     Wd Sdng        NaN
# 766           1988     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 767           1985     Gable  CompShg     VinylSd     VinylSd        NaN
# 786           1950     Gable  CompShg     MetalSd     MetalSd        NaN
# 794           1996     Gable  CompShg     MetalSd     MetalSd        NaN
# 800           1997     Gable  CompShg     VinylSd     VinylSd        NaN
# 812           1952       Hip  CompShg     Wd Sdng     Wd Sdng        NaN
# 813           1958     Gable  CompShg     MetalSd     MetalSd    BrkFace
# 867           1961     Gable  CompShg     VinylSd     VinylSd        NaN
# 873           1950     Gable  CompShg     HdBoard     HdBoard        NaN
# 878           1995     Gable  CompShg     HdBoard     HdBoard        NaN
# 890           2006     Gable  CompShg     MetalSd     MetalSd        NaN
# 912           1950     Gable  CompShg     MetalSd     MetalSd        NaN
# 953           1969     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 1061          1950     Gable  CompShg     MetalSd     MetalSd        NaN
# 1076          1989     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 1083          1964       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1171          1958       Hip  CompShg     MetalSd     MetalSd        NaN
# 1200          1970     Gable  CompShg     MetalSd     MetalSd        NaN
# 1210          1992     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 1230          1977      Shed  CompShg     Plywood     Plywood        NaN
# 1252          1968     Gable  CompShg     HdBoard     HdBoard        NaN
# 1328          1950     Gable  CompShg     BrkFace     Wd Sdng        NaN
# 1386          1978     Gable  CompShg     Plywood     Plywood    BrkFace
# 1457          2006     Gable  CompShg     CemntBd     CmentBd        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 5            0.0        TA        TA       Wood       Gd       TA
# 7          240.0        TA        TA     CBlock       Gd       TA
# 16         180.0        TA        TA     CBlock       TA       TA
# 17           0.0        TA        TA       Slab      NaN      NaN
# 51           0.0        TA        TA      PConc       TA       TA
# 84          22.0        TA        TA      PConc       Gd       TA
# 95          68.0        Ex        Gd      PConc       Gd       Gd
# 98           0.0        TA        TA     BrkTil       TA       TA
# 99           0.0        TA        TA     CBlock       TA       TA
# 106          0.0        TA        TA     BrkTil       Fa       TA
# 214        153.0        TA        TA     CBlock       Gd       TA
# 249        472.0        Gd        TA     CBlock       Gd       TA
# 250          0.0        TA        Po     CBlock       TA       TA
# 335          0.0        TA        TA     CBlock       TA       TA
# 338          0.0        Gd        TA     CBlock       Gd       TA
# 346          0.0        TA        Gd     CBlock       TA       TA
# 392          0.0        TA        TA       Slab      NaN      NaN
# 439          0.0        TA        TA     BrkTil       TA       Fa
# 499          0.0        TA        TA     CBlock       TA       TA
# 502          0.0        TA        TA     CBlock       TA       TA
# 510         70.0        Gd        TA     CBlock       TA       TA
# 539        479.0        Gd        TA      PConc       Gd       TA
# 589          0.0        TA        TA     BrkTil       TA       TA
# 611        233.0        TA        TA     CBlock       Gd       TA
# 626          0.0        TA        TA     CBlock       TA       TA
# 634          0.0        TA        TA     CBlock       TA       TA
# 705          0.0        Fa        Fa       Slab      NaN      NaN
# 725          0.0        TA        TA     CBlock       TA       TA
# 733          0.0        TA        TA     CBlock       TA       TA
# 760          0.0        TA        TA     CBlock       TA       TA
# 766         42.0        TA        TA     CBlock       Gd       TA
# 767          0.0        TA        TA     CBlock       Gd       TA
# 786          0.0        TA        Gd      PConc       Fa       TA
# 794          0.0        Gd        TA      PConc       Gd       TA
# 800          0.0        TA        TA      PConc       Gd       TA
# 812          0.0        Fa        TA     CBlock       TA       TA
# 813        243.0        TA        TA     CBlock       TA       TA
# 867          0.0        TA        TA     CBlock       TA       TA
# 873          0.0        Gd        TA     CBlock       TA       TA
# 878          0.0        TA        TA     CBlock       TA       TA
# 890          0.0        TA        Gd     CBlock       TA       TA
# 912          0.0        TA        TA     BrkTil       TA       TA
# 953        232.0        TA        TA     CBlock       TA       TA
# 1061         0.0        Fa        TA     CBlock       TA       TA
# 1076         0.0        TA        TA     CBlock       Fa       TA
# 1083       425.0        TA        TA     CBlock       TA       TA
# 1171         0.0        TA        TA     CBlock       TA       TA
# 1200         0.0        TA        TA     CBlock       TA       TA
# 1210         0.0        Gd        TA      PConc       Gd       TA
# 1230         1.0        TA        TA     CBlock       Gd       TA
# 1252         0.0        TA        TA     CBlock       TA       TA
# 1328         0.0        Gd        Gd     BrkTil       Gd       TA
# 1386       184.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 5              No          GLQ         732          Unf           0
# 7              Mn          ALQ         859          BLQ          32
# 16             No          ALQ         578          Unf           0
# 17            NaN          NaN           0          NaN           0
# 51             No          Unf           0          Unf           0
# 84             No          Unf           0          Unf           0
# 95             No          ALQ         310          Unf           0
# 98             No          ALQ         108          Unf           0
# 99             No          ALQ         569          Unf           0
# 106            No          Unf           0          Unf           0
# 214            No          GLQ         378          Unf           0
# 249            Gd          Rec         697          Unf           0
# 250            No          Unf           0          Unf           0
# 335            Gd          ALQ        1249          BLQ         147
# 338            Mn          ALQ         213          Unf           0
# 346            Mn          BLQ         498          Unf           0
# 392           NaN          NaN           0          NaN           0
# 439            Mn          Unf           0          Unf           0
# 499            No          BLQ         111          LwQ         279
# 502            No          ALQ         698          GLQ          96
# 510            No          BLQ         650          Rec         180
# 539            Av          GLQ        1358          Unf           0
# 589            No          Unf           0          Unf           0
# 611            Av          ALQ         605          Unf           0
# 626            No          Unf           0          Unf           0
# 634            No          GLQ        1056          Unf           0
# 705           NaN          NaN           0          NaN           0
# 725            No          ALQ         375          BLQ         239
# 733            No          BLQ         594          Unf           0
# 760            No          Rec         612          Unf           0
# 766            No          GLQ         394          Unf           0
# 767            Mn          ALQ         660          Unf           0
# 786            No          LwQ         686          Unf           0
# 794            No          Unf           0          Unf           0
# 800            Gd          GLQ         462          Unf           0
# 812            Av          Unf           0          Unf           0
# 813            No          Rec         608          Unf           0
# 867            No          ALQ         932          Unf           0
# 873            No          Rec         375          Unf           0
# 878            Av          ALQ         899          Unf           0
# 890            Mn          Unf           0          Unf           0
# 912            No          Rec         489          Unf           0
# 953            Av          ALQ         562          LwQ         193
# 1061           No          Unf           0          Unf           0
# 1076           No          ALQ         626          Unf           0
# 1083           No          BLQ         553          Unf           0
# 1171           No          ALQ         662          Unf           0
# 1200           No          Unf           0          Unf           0
# 1210           No          Unf           0          Unf           0
# 1230           No          GLQ         498          Rec         211
# 1252           No          BLQ         510          Unf           0
# 1328           No          LwQ         493          Unf           0
# 1386           No          BLQ         790          LwQ         469
# 1457           No          GLQ         275          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 5            64          796    GasA        Ex          Y      SBrkr
# 7           216         1107    GasA        Ex          Y      SBrkr
# 16          426         1004    GasA        Ex          Y      SBrkr
# 17            0            0    GasA        TA          Y      SBrkr
# 51          816          816    GasA        TA          Y      SBrkr
# 84          384          384    GasA        Gd          Y      SBrkr
# 95          370          680    GasA        Gd          Y      SBrkr
# 98          350          458    GasA        Fa          N      SBrkr
# 99          381          950    GasA        Fa          Y      SBrkr
# 106         641          641    GasA        Gd          Y      SBrkr
# 214         311          689    GasA        Ex          Y      SBrkr
# 249         747         1444    GasA        Gd          Y      SBrkr
# 250         728          728    GasA        Ex          Y      SBrkr
# 335         103         1499    GasA        Ex          Y      SBrkr
# 338         995         1208    GasA        Ex          Y      SBrkr
# 346         460          958    GasA        TA          Y      SBrkr
# 392           0            0    GasA        TA          Y      SBrkr
# 439         684          684    GasA        Gd          Y      SBrkr
# 499         522          912    GasA        Fa          Y      SBrkr
# 502         420         1214    GasA        Ex          Y      SBrkr
# 510         178         1008    GasA        Ex          Y      SBrkr
# 539         223         1581    GasA        Ex          Y      SBrkr
# 589         742          742    GasA        TA          Y      FuseA
# 611         427         1032    GasA        TA          Y      SBrkr
# 626         978          978    GasA        TA          Y      SBrkr
# 634           0         1056    GasA        Gd          Y      SBrkr
# 705           0            0    GasA        Fa          N      SBrkr
# 725         250          864    GasA        TA          Y      SBrkr
# 733         270          864    GasA        Ex          Y      SBrkr
# 760         252          864    GasA        Ex          Y      SBrkr
# 766         586          980    GasA        TA          Y      SBrkr
# 767         323          983    GasA        Ex          Y      SBrkr
# 786           0          686    GasA        TA          Y      SBrkr
# 794         712          712    GasA        Ex          Y      SBrkr
# 800         154          616    GasA        Gd          Y      SBrkr
# 812         540          540    GasA        TA          N      FuseA
# 813         834         1442    GasA        Gd          Y      SBrkr
# 867         108         1040    GasA        TA          Y      SBrkr
# 873         457          832    GasA        Gd          Y      SBrkr
# 878         210         1109    GasA        TA          Y      SBrkr
# 890         672          672    GasA        Ex          Y      SBrkr
# 912         279          768    GasA        TA          N      SBrkr
# 953          29          784    GasA        Ex          Y      SBrkr
# 1061        894          894    GasA        TA          Y      SBrkr
# 1076        170          796    GasA        Gd          Y      SBrkr
# 1083        698         1251    GasA        TA          Y      SBrkr
# 1171        599         1261    GasA        Ex          Y      SBrkr
# 1200        864          864    GasA        Gd          Y      SBrkr
# 1210       1055         1055    GasA        Ex          Y      SBrkr
# 1230        652         1361    GasA        Ex          Y      SBrkr
# 1252        354          864    GasA        TA          Y      SBrkr
# 1328       1017         1510    GasW        Ex          Y      SBrkr
# 1386        133         1392    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 5          796       566             0       1362             1             0
# 7         1107       983             0       2090             1             0
# 16        1004         0             0       1004             1             0
# 17        1296         0             0       1296             0             0
# 51         816         0           360       1176             0             0
# 84         804       670             0       1474             0             0
# 95         680       790             0       1470             0             0
# 98         835         0             0        835             0             0
# 99        1225         0             0       1225             1             0
# 106       1047         0             0       1047             0             0
# 214        689       703             0       1392             0             0
# 249       1444       700             0       2144             0             1
# 250       1306         0             0       1306             0             0
# 335       1619       167             0       1786             2             0
# 338       1621         0             0       1621             1             0
# 346        958         0             0        958             0             0
# 392        882         0             0        882             0             0
# 439        684       512             0       1196             0             0
# 499        912         0             0        912             0             1
# 502       1214         0             0       1214             1             0
# 510       1363         0             0       1363             1             0
# 539       1601         0             0       1601             1             0
# 589        779         0           156        935             0             0
# 611       1032         0             0       1032             0             1
# 626       1422         0             0       1422             0             0
# 634       1056         0             0       1056             2             0
# 705        372       720             0       1092             0             0
# 725        864         0             0        864             0             0
# 733       1144         0             0       1144             1             0
# 760        864         0             0        864             0             0
# 766        980       734             0       1714             0             0
# 767        983       767             0       1750             1             0
# 786        966       686             0       1652             1             0
# 794       1086       809             0       1895             0             0
# 800        616      1072             0       1688             1             0
# 812       1044         0             0       1044             0             0
# 813       1442         0             0       1442             0             0
# 867       1120         0             0       1120             1             0
# 873       1036         0           232       1268             0             0
# 878       1155         0             0       1155             1             0
# 890        672       252             0        924             0             0
# 912       1015         0             0       1015             0             0
# 953       1168       800             0       1968             0             1
# 1061       894         0             0        894             0             0
# 1076      1096       370             0       1466             0             1
# 1083      1251         0             0       1251             1             0
# 1171      1261         0             0       1261             1             0
# 1200       864         0             0        864             0             0
# 1210      1055       790             0       1845             0             0
# 1230      1361      1259             0       2620             0             0
# 1252       874         0             0        874             1             0
# 1328      1584      1208             0       2792             0             0
# 1386      1392      1392             0       2784             1             0
# 1457      1188      1152             0       2340             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 5            1         1             1             1          TA
# 7            2         1             3             1          TA
# 16           1         0             2             1          TA
# 17           2         0             2             2          TA
# 51           1         0             3             1          TA
# 84           2         1             3             1          TA
# 95           2         1             3             1          TA
# 98           1         0             2             1          TA
# 99           1         1             3             1          TA
# 106          1         0             2             1          TA
# 214          1         1             3             1          TA
# 249          2         0             4             1          Gd
# 250          1         0             3             1          Fa
# 335          2         0             3             1          TA
# 338          2         0             3             1          Gd
# 346          1         0             2             1          TA
# 392          1         0             3             1          TA
# 439          1         0             3             1          Gd
# 499          1         0             2             1          TA
# 502          1         0             2             1          TA
# 510          1         0             2             1          TA
# 539          2         0             3             1          Gd
# 589          1         0             2             1          TA
# 611          2         0             3             1          TA
# 626          1         0             3             1          TA
# 634          0         0             0             2          TA
# 705          2         0             3             2          Fa
# 725          1         0             3             1          Gd
# 733          1         0             3             1          TA
# 760          1         0             2             1          TA
# 766          2         1             3             1          TA
# 767          2         0             4             1          TA
# 786          2         0             4             1          TA
# 794          2         1             3             1          Gd
# 800          2         1             4             1          Gd
# 812          1         0             2             1          Fa
# 813          1         1             4             1          TA
# 867          1         1             3             1          Fa
# 873          1         0             3             1          TA
# 878          1         0             3             1          Gd
# 890          1         0             3             1          TA
# 912          1         0             3             1          TA
# 953          2         1             4             1          TA
# 1061         1         0             2             1          TA
# 1076         2         0             3             1          Gd
# 1083         1         0             3             1          TA
# 1171         1         0             3             1          TA
# 1200         1         0             3             1          TA
# 1210         2         1             3             1          Gd
# 1230         2         2             4             2          TA
# 1252         1         0             3             1          TA
# 1328         2         0             5             1          TA
# 1386         3         1             5             1          Gd
# 1457         2         0             4             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 5                5        Typ           0         NaN     Attchd       1993.0
# 7                7        Typ           2          TA     Attchd       1973.0
# 16               5        Typ           1          TA     Attchd       1970.0
# 17               6        Typ           0         NaN    CarPort       1967.0
# 51               6        Typ           1          Gd     Detchd       1985.0
# 84               7        Typ           1          TA    BuiltIn       1995.0
# 95               6        Typ           1          TA    BuiltIn       1993.0
# 98               5        Typ           0         NaN    Basment       1920.0
# 99               6        Typ           0         NaN        NaN          NaN
# 106              6        Typ           0         NaN     Detchd       1954.0
# 214              6        Typ           0         NaN     Attchd       1977.0
# 249              7        Typ           2          TA     Attchd       1958.0
# 250              6        Mod           0         NaN        NaN          NaN
# 335              7        Typ           2          Gd     Attchd       1965.0
# 338              8        Typ           0         NaN     Attchd       1984.0
# 346              5        Typ           0         NaN     Attchd       1960.0
# 392              5        Typ           0         NaN     Attchd       1959.0
# 439              7        Typ           0         NaN     Detchd       2005.0
# 499              5        Typ           0         NaN     Attchd       1958.0
# 502              6        Typ           0         NaN     Detchd       1965.0
# 510              6       Min1           2          TA    CarPort       1951.0
# 539              6        Typ           1          TA     Attchd       2001.0
# 589              4        Typ           0         NaN     Detchd       1988.0
# 611              6        Typ           1          TA     Attchd       1978.0
# 626              6       Min1           1          TA     Attchd       1960.0
# 634              4        Typ           0         NaN     Detchd       1980.0
# 705              7        Mod           0         NaN        NaN          NaN
# 725              5        Typ           0         NaN     Detchd       1989.0
# 733              6        Typ           1          TA     Attchd       1961.0
# 760              5        Typ           0         NaN     Detchd       2008.0
# 766              7        Typ           1          TA     Attchd       1988.0
# 767              7        Mod           0         NaN     Attchd       1989.0
# 786              7        Typ           0         NaN     Detchd       1961.0
# 794              7        Typ           1          TA     Attchd       1994.0
# 800              8        Typ           0         NaN     Attchd       1997.0
# 812              4        Typ           0         NaN    Basment       1952.0
# 813              7        Typ           0         NaN     Attchd       1958.0
# 867              5        Typ           0         NaN     Attchd       1961.0
# 873              6        Typ           1          Gd     Attchd       1949.0
# 878              6       Min2           0         NaN     Detchd       1987.0
# 890              6        Typ           1          Po     Detchd       2003.0
# 912              6       Min1           0         NaN     Detchd       1925.0
# 953              7       Min2           1          Po     Attchd       1969.0
# 1061             6        Typ           0         NaN     Detchd       1994.0
# 1076             7       Min1           1          TA     Attchd       1950.0
# 1083             6        Typ           2          Gd     Attchd       1964.0
# 1171             6        Typ           1          TA     Attchd       1958.0
# 1200             5        Typ           0         NaN     Attchd       1972.0
# 1210             8        Typ           1          TA     Attchd       1992.0
# 1230            12        Typ           1          TA    BuiltIn       1977.0
# 1252             5        Typ           0         NaN     Attchd       1968.0
# 1328             8        Mod           2          TA     Detchd       1920.0
# 1386            12        Typ           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 5             Unf           2         480         TA         TA          Y
# 7             RFn           2         484         TA         TA          Y
# 16            Fin           2         480         TA         TA          Y
# 17            Unf           2         516         TA         TA          Y
# 51            Unf           2         528         TA         TA          Y
# 84            Fin           2         400         TA         TA          Y
# 95            Fin           2         420         TA         TA          Y
# 98            Unf           1         366         Fa         TA          Y
# 99            NaN           0           0        NaN        NaN          Y
# 106           Unf           1         273         Fa         Fa          N
# 214           Fin           1         299         TA         TA          Y
# 249           Fin           2         389         TA         TA          Y
# 250           NaN           0           0        NaN        NaN          Y
# 335           Fin           2         529         TA         TA          Y
# 338           RFn           2         440         TA         TA          Y
# 346           RFn           1         301         TA         TA          Y
# 392           RFn           1         294         TA         TA          Y
# 439           Unf           2         528         TA         TA          Y
# 499           Fin           1         297         TA         TA          Y
# 502           Unf           2         461         Fa         Fa          Y
# 510           Unf           1         288         TA         TA          Y
# 539           RFn           2         670         TA         TA          Y
# 589           Unf           1         308         TA         TA          P
# 611           Unf           2         564         TA         TA          Y
# 626           RFn           1         286         TA         TA          Y
# 634           Unf           2         576         TA         TA          Y
# 705           NaN           0           0        NaN        NaN          N
# 725           Unf           2         660         TA         TA          Y
# 733           RFn           1         264         TA         TA          Y
# 760           Unf           1         300         Ex         Ex          Y
# 766           Unf           2         496         TA         TA          Y
# 767           Unf           1         423         TA         TA          Y
# 786           Unf           1         416         TA         TA          Y
# 794           Fin           2         409         TA         TA          Y
# 800           RFn           2         603         TA         TA          Y
# 812           Unf           2         504         TA         TA          N
# 813           RFn           1         301         TA         TA          Y
# 867           RFn           2         544         TA         TA          Y
# 873           Unf           1         288         TA         TA          Y
# 878           Unf           2         576         TA         TA          Y
# 890           Unf           2         576         TA         TA          Y
# 912           Unf           1         450         TA         TA          Y
# 953           RFn           2         530         TA         TA          Y
# 1061          RFn           3        1248         TA         TA          Y
# 1076          Unf           2         566         TA         TA          Y
# 1083          RFn           1         461         TA         TA          Y
# 1171          RFn           2         433         TA         TA          Y
# 1200          Unf           1         280         TA         TA          Y
# 1210          RFn           2         462         TA         TA          Y
# 1230          RFn           2         600         TA         TA          N
# 1252          RFn           1         288         TA         TA          Y
# 1328          Unf           2         520         Fa         TA          Y
# 1386          RFn           2         564         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 5             40           30              0        320            0
# 7            235          204            228          0            0
# 16             0            0              0          0            0
# 17             0            0              0          0            0
# 51           112            0              0          0            0
# 84           120           72              0          0            0
# 95           232           63              0          0            0
# 98             0            0             77          0            0
# 99           352            0              0          0            0
# 106            0            0              0          0            0
# 214            0           36              0          0            0
# 249            0           98              0          0            0
# 250          263            0              0          0            0
# 335          670            0              0          0            0
# 338          108           45              0          0            0
# 346            0            0              0          0            0
# 392            0            0              0          0            0
# 439            0           46              0          0            0
# 499           12          285              0          0            0
# 502            0            0            184          0            0
# 510          324           42              0          0          168
# 539          180            0              0          0            0
# 589            0            0              0          0            0
# 611            0            0              0          0            0
# 626            0            0             36          0            0
# 634          264           56              0          0            0
# 705            0            0              0          0            0
# 725           96            0              0          0            0
# 733          165            0              0          0            0
# 760            0            0              0          0            0
# 766          228           66            156          0            0
# 767          245            0            156          0            0
# 786            0            0            196          0            0
# 794          143           46              0          0            0
# 800          403          114            185          0            0
# 812            0            0              0          0            0
# 813            0            0            275          0            0
# 867          168            0              0          0            0
# 873            0           28              0          0            0
# 878          192            0              0          0            0
# 890            0            0              0          0            0
# 912            0            0            112          0          120
# 953          305          189              0          0            0
# 1061           0           20              0          0            0
# 1076         436           21              0          0            0
# 1083           0          116              0          0            0
# 1171           0            0              0          0          288
# 1200           0            0              0          0            0
# 1210         635          104              0          0            0
# 1230         155           24            145          0            0
# 1252          33            0              0          0            0
# 1328           0          547              0          0          480
# 1386           0          112              0          0          440
# 1457           0           60              0          0            0
#
#       PoolArea  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 5            0  MnPrv        Shed      700      10    2009       WD
# 7            0    NaN        Shed      350      11    2009       WD
# 16           0    NaN        Shed      700       3    2010       WD
# 17           0    NaN        Shed      500      10    2006       WD
# 51           0  MnPrv        Shed      400       9    2006       WD
# 84           0    NaN        Shed      700       5    2009       WD
# 95           0    NaN        Shed      480       4    2009       WD
# 98           0    NaN        Shed      400       5    2010      COD
# 99           0    NaN        Shed      400       1    2010       WD
# 106          0    NaN        Shed      450       8    2007       WD
# 214          0  MnPrv        Shed      450       3    2010       WD
# 249          0    NaN        Shed      500       6    2007       WD
# 250          0   GdWo        Shed      450       5    2010       WD
# 335          0    NaN        Shed      700       8    2008       WD
# 338          0    NaN        Shed      400       5    2006       WD
# 346          0    NaN        Gar2    15500       4    2007       WD
# 392          0  MnPrv        Shed     1200       7    2007       WD
# 439          0  GdPrv        Shed      800       8    2009    ConLI
# 499          0   MnWw        Shed      480       6    2007       WD
# 502          0  GdPrv        Shed      400       4    2007       WD
# 510          0    NaN        Shed     2000       6    2009       WD
# 539          0  MnPrv        Shed     2000       5    2010       WD
# 589          0    NaN        Shed      600       8    2008       WD
# 611          0  MnPrv        Shed      500       7    2007       WD
# 626          0   GdWo        Shed      600       8    2007       WD
# 634          0  GdPrv        Shed      600       6    2010       WD
# 705          0    NaN        Othr     3500       7    2010       WD
# 725          0    NaN        Shed      500      11    2009       WD
# 733          0   GdWo        Shed      400       3    2009       WD
# 760          0    NaN        Shed      450      10    2009       WD
# 766          0  MnPrv        Shed      500       3    2010       WD
# 767          0    NaN        Shed     1300       7    2008       WD
# 786          0    NaN        Shed     1200       6    2010       WD
# 794          0    NaN        Shed      500      10    2008       WD
# 800          0    NaN        Shed      400       5    2008       WD
# 812          0    NaN        Shed       54       6    2010       WD
# 813          0    NaN        Shed      500       4    2007      COD
# 867          0    NaN        Shed      400       5    2007       WD
# 873          0    NaN        Othr        0       9    2009       WD
# 878          0  MnPrv        Shed      400       6    2010       WD
# 890          0  MnPrv        Shed     2000       7    2007       WD
# 912          0  MnPrv        Shed      620       7    2006       WD
# 953          0  MnPrv        Shed      400       9    2008       WD
# 1061         0    NaN        Shed      560       8    2008    ConLD
# 1076         0    NaN        Shed      500       4    2006       WD
# 1083         0  MnPrv        Shed      700       3    2006       WD
# 1171         0    NaN        Shed     1400      11    2008       WD
# 1200         0    NaN        Shed        0       7    2006      Oth
# 1210         0  GdPrv        Shed      400       5    2010       WD
# 1230         0    NaN        Gar2     8300       8    2007       WD
# 1252         0   GdWo        Shed      600      11    2009       WD
# 1328         0  MnPrv        Shed     1150       6    2008       WD
# 1386       519  MnPrv        TenC     2000       7    2006       WD
# 1457         0  GdPrv        Shed     2500       5    2010       WD
#
#      SaleCondition  SalePrice
# 5           Normal     143000
# 7           Normal     200000
# 16          Normal     149000
# 17          Normal      90000
# 51          Normal     114500
# 84          Normal     168500
# 95          Normal     185000
# 98         Abnorml      83000
# 99          Normal     128950
# 106         Normal     100000
# 214         Normal     161750
# 249         Normal     277000
# 250         Normal      76500
# 335         Normal     228950
# 338         Normal     202500
# 346         Normal     151500
# 392         Normal     106500
# 439         Normal     110000
# 499         Normal     120000
# 502         Normal     140000
# 510         Normal     164900
# 539         Normal     272000
# 589         Normal      79500
# 611         Normal     148000
# 626         Normal     139900
# 634         Normal     144000
# 705         Normal      55000
# 725         Normal     120500
# 733         Normal     131400
# 760         Normal     127500
# 766         Normal     196500
# 767         Normal     160000
# 786         Normal     139000
# 794         Normal     194500
# 800         Normal     200000
# 812         Alloca      55993
# 813         Normal     157900
# 867         Normal     129000
# 873         Normal     133000
# 878         Normal     148000
# 890         Normal     122900
# 912        Abnorml      88000
# 953         Normal     172000
# 1061        Normal      81000
# 1076        Normal     170000
# 1083        Normal     160000
# 1171        Normal     163000
# 1200       Abnorml     116050
# 1210        Normal     189000
# 1230        Normal     190000
# 1252        Normal     130000
# 1328        Normal     256000
# 1386        Normal     250000
# 1457        Normal     266500

# %%
df['MiscFeature'].value_counts()
# Out:
# MiscFeature
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: count, dtype: int64

# %%
if 'MiscFeature' in df.columns:
    pass
    df.drop(columns = 'MiscFeature', inplace = True)
    

print('Number of columns: ' + str(len(df.columns)))
# Out:
# Number of columns: 79

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea Fence  MiscVal  MoSold  YrSold SaleType  \
# 0            0         0   NaN        0       2    2008       WD
# 1            0         0   NaN        0       5    2007       WD
# 2            0         0   NaN        0       9    2008       WD
# 3            0         0   NaN        0       2    2006       WD
# 4            0         0   NaN        0      12    2008       WD
#
#   SaleCondition  SalePrice
# 0        Normal     208500
# 1        Normal     181500
# 2        Normal     223500
# 3       Abnorml     140000
# 4        Normal     250000

# %% [markdown]
# Alley: Type of alley access to property
# In below step, upon inspecting the "Alley" column, it was observed that only 91 dwellings have values for this feature. Given the limited data and the potential challenges in imputing missing values, it appears reasonable to consider dropping this column. Instead, the "Street: Type of road access to property " column can be utilized to identifytype of alley access to propertyl, as it provides more comprehensive information in this regard.

# %%
df.loc[~df['Alley'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg
# 30      31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 56      57         160       FV         24.0     2645   Pave  Pave      Reg
# 79      80          50       RM         60.0    10440   Pave  Grvl      Reg
# 87      88         160       FV         40.0     3951   Pave  Pave      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1404  1405          50       RL         60.0    10410   Pave  Grvl      Reg
# 1414  1415          50       RL         64.0    13053   Pave  Pave      Reg
# 1427  1428          50       RL         60.0    10930   Pave  Grvl      Reg
# 1432  1433          30       RL         60.0    10800   Pave  Grvl      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 21           Bnk    AllPub    Inside       Gtl       IDOTRR       Norm
# 30           Lvl    AllPub    Inside       Gtl       IDOTRR      Feedr
# 56           Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 79           Lvl    AllPub    Corner       Gtl      OldTown       Norm
# 87           Lvl    AllPub    Corner       Gtl      Somerst       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1404         Lvl    AllPub    Corner       Gtl      OldTown     Artery
# 1414         Bnk    AllPub    Inside       Gtl      BrkSide       Norm
# 1427         Bnk    AllPub    Inside       Gtl        NAmes     Artery
# 1432         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1454         Lvl    AllPub    Inside       Gtl      Somerst       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 21         Norm     1Fam     1.5Unf            7            7       1930
# 30         Norm     1Fam     2Story            4            4       1920
# 56         Norm    Twnhs     2Story            8            5       1999
# 79         Norm     1Fam     2Story            5            6       1910
# 87         Norm   TwnhsE     2Story            6            5       2009
# ...         ...      ...        ...          ...          ...        ...
# 1404       Norm     1Fam     1.5Fin            3            4       1915
# 1414       Norm     1Fam     1.5Fin            6            7       1923
# 1427       Norm     1Fam     1.5Fin            5            6       1945
# 1432       Norm     1Fam     1Story            4            6       1927
# 1454       Norm     1Fam     1Story            7            5       2004
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 21            1950     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 30            1950   Gambrel  CompShg     BrkFace     BrkFace        NaN
# 56            2000     Gable  CompShg     MetalSd     MetalSd    BrkFace
# 79            1981     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 87            2009     Gable  CompShg     VinylSd     VinylSd      Stone
# ...            ...       ...      ...         ...         ...        ...
# 1404          1950     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 1414          2000   Gambrel  CompShg     Wd Sdng     Wd Sdng        NaN
# 1427          1950     Gable  CompShg     MetalSd     MetalSd        NaN
# 1432          2007     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 1454          2005     Gable  CompShg     VinylSd     VinylSd        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 21           0.0        TA        TA      PConc       TA       TA
# 30           0.0        TA        Fa     BrkTil       TA       TA
# 56         456.0        Gd        TA      PConc       Gd       TA
# 79           0.0        TA        TA      PConc       TA       TA
# 87          76.0        Gd        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1404         0.0        TA        TA      PConc       TA       TA
# 1414         0.0        TA        TA     BrkTil       TA       TA
# 1427         0.0        TA        TA     CBlock       TA       TA
# 1432         0.0        TA        TA     BrkTil       TA       TA
# 1454         0.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 21             No          Unf           0          Unf           0
# 30             No          Unf           0          Unf           0
# 56             No          GLQ         649          Unf           0
# 79             No          Unf           0          Unf           0
# 87             Av          Unf           0          Unf           0
# ...           ...          ...         ...          ...         ...
# 1404           No          Unf           0          Unf           0
# 1414           No          Unf           0          Unf           0
# 1427           No          BLQ         580          Unf           0
# 1432           No          Unf           0          Unf           0
# 1454           No          GLQ         410          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 21          637          637    GasA        Ex          Y      FuseF
# 30          649          649    GasA        TA          N      SBrkr
# 56          321          970    GasA        Ex          Y      SBrkr
# 79          440          440    GasA        Gd          Y      SBrkr
# 87          612          612    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1404        672          672    GasA        TA          Y      SBrkr
# 1414        833          833    GasA        Gd          Y      SBrkr
# 1427        333          913    GasA        TA          Y      FuseA
# 1432        656          656    GasA        TA          Y      SBrkr
# 1454        811         1221    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 21        1108         0             0       1108             0             0
# 30         649       668             0       1317             0             0
# 56         983       756             0       1739             1             0
# 79         682       548             0       1230             0             0
# 87         612       612             0       1224             0             0
# ...        ...       ...           ...        ...           ...           ...
# 1404       694       520             0       1214             0             0
# 1414      1053       795             0       1848             0             0
# 1427      1048       510             0       1558             1             0
# 1432       968         0             0        968             0             0
# 1454      1221         0             0       1221             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 21           1         0             3             1          Gd
# 30           1         0             3             1          TA
# 56           2         1             3             1          Gd
# 79           1         1             2             1          TA
# 87           2         1             2             1          Gd
# ...        ...       ...           ...           ...         ...
# 1404         1         0             3             1          TA
# 1414         1         1             4             1          Gd
# 1427         1         1             3             1          TA
# 1432         2         0             4             1          TA
# 1454         2         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 21               6        Typ           1          Gd     Attchd       1930.0
# 30               6        Typ           0         NaN     Detchd       1920.0
# 56               7        Typ           0         NaN     Attchd       1999.0
# 79               5        Typ           0         NaN     Detchd       1966.0
# 87               4        Typ           0         NaN     Detchd       2009.0
# ...            ...        ...         ...         ...        ...          ...
# 1404             6        Typ           0         NaN     Detchd       1998.0
# 1414             8        Typ           1          Gd     Detchd       1922.0
# 1427             6        Typ           1          TA     Attchd       1962.0
# 1432             5        Typ           0         NaN     Detchd       1928.0
# 1454             6        Typ           0         NaN     Attchd       2004.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 21            Unf           1         280         TA         TA          N
# 30            Unf           1         250         TA         Fa          N
# 56            Fin           2         480         TA         TA          Y
# 79            Unf           2         440         TA         TA          Y
# 87            RFn           2         528         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1404          Unf           3         936         TA         TA          Y
# 1414          Unf           2         370         TA         TA          N
# 1427          Unf           1         288         TA         TA          Y
# 1432          Unf           1         216         Fa         Fa          Y
# 1454          RFn           2         400         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 21             0            0            205          0            0
# 30             0           54            172          0            0
# 56           115            0              0          0            0
# 79            74            0            128          0            0
# 87             0          234              0          0            0
# ...          ...          ...            ...        ...          ...
# 1404         216            0            160          0            0
# 1414           0            0              0          0          220
# 1427           0            0              0          0            0
# 1432           0            0              0          0            0
# 1454           0          113              0          0            0
#
#       PoolArea  Fence  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# 21           0  GdPrv        0       6    2007       WD        Normal
# 30           0  MnPrv        0       7    2008       WD        Normal
# 56           0    NaN        0       8    2009       WD       Abnorml
# 79           0  MnPrv        0       5    2009       WD        Normal
# 87           0    NaN        0       6    2009      New       Partial
# ...        ...    ...      ...     ...     ...      ...           ...
# 1404         0  MnPrv        0       1    2006       WD        Family
# 1414         0    NaN        0       6    2008       WD        Normal
# 1427         0    NaN        0       4    2008       WD        Normal
# 1432         0    NaN        0       8    2007       WD        Normal
# 1454         0    NaN        0      10    2009       WD        Normal
#
#       SalePrice
# 21       139400
# 30        40000
# 56       172500
# 79       110000
# 87       164500
# ...         ...
# 1404     105000
# 1414     207000
# 1427     140000
# 1432      64500
# 1454     185000
#
# [91 rows x 79 columns]

# %%
if 'Alley' in df.columns:
    pass
    df.drop(columns = 'Alley', inplace = True)

print('Number of columns: ' + str(len(df.columns)))
# Out:
# Number of columns: 78

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
# 1     1Story            6            8       1976          1976     Gable
# 2     2Story            7            5       2001          2002     Gable
# 3     2Story            7            5       1915          1970     Gable
# 4     2Story            8            5       2000          2000     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     VinylSd     VinylSd    BrkFace       196.0        Gd        TA
# 1  CompShg     MetalSd     MetalSd        NaN         0.0        TA        TA
# 2  CompShg     VinylSd     VinylSd    BrkFace       162.0        Gd        TA
# 3  CompShg     Wd Sdng     Wd Shng        NaN         0.0        TA        TA
# 4  CompShg     VinylSd     VinylSd    BrkFace       350.0        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0      PConc       Gd       TA           No          GLQ         706
# 1     CBlock       Gd       TA           Gd          ALQ         978
# 2      PConc       Gd       TA           Mn          GLQ         486
# 3     BrkTil       TA       Gd           No          ALQ         216
# 4      PConc       Gd       TA           Av          GLQ         655
#
#   BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC  \
# 0          Unf           0        150          856    GasA        Ex
# 1          Unf           0        284         1262    GasA        Ex
# 2          Unf           0        434          920    GasA        Ex
# 3          Unf           0        540          756    GasA        Gd
# 4          Unf           0        490         1145    GasA        Ex
#
#   CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          Y      SBrkr       856       854             0       1710
# 1          Y      SBrkr      1262         0             0       1262
# 2          Y      SBrkr       920       866             0       1786
# 3          Y      SBrkr       961       756             0       1717
# 4          Y      SBrkr      1145      1053             0       2198
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0             1             0         2         1             3             1
# 1             0             1         2         0             3             1
# 2             1             0         2         1             3             1
# 3             1             0         1         0             3             1
# 4             1             0         2         1             4             1
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  \
# 0          Gd             8        Typ           0         NaN     Attchd
# 1          TA             6        Typ           1          TA     Attchd
# 2          Gd             6        Typ           1          TA     Attchd
# 3          Gd             7        Typ           1          Gd     Detchd
# 4          Gd             9        Typ           1          TA     Attchd
#
#    GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 0       2003.0          RFn           2         548         TA         TA
# 1       1976.0          RFn           2         460         TA         TA
# 2       2001.0          RFn           2         608         TA         TA
# 3       1998.0          Unf           3         642         TA         TA
# 4       2000.0          RFn           3         836         TA         TA
#
#   PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0          Y           0           61              0          0            0
# 1          Y         298            0              0          0            0
# 2          Y           0           42              0          0            0
# 3          Y           0           35            272          0            0
# 4          Y         192           84              0          0            0
#
#    PoolArea Fence  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# 0         0   NaN        0       2    2008       WD        Normal     208500
# 1         0   NaN        0       5    2007       WD        Normal     181500
# 2         0   NaN        0       9    2008       WD        Normal     223500
# 3         0   NaN        0       2    2006       WD       Abnorml     140000
# 4         0   NaN        0      12    2008       WD        Normal     250000

# %% [markdown]
# Fence: Fence quality
# During the assessment of the 'Fence' column, it was noted that 'NA' values indicate the absence of a fence for the respective houses. Given this interpretation, it's essential to retain this column to determine whether a dwelling has a fence or not. To enhance clarity and consistency, the 'NA' values should be replaced with 'No Fence'.

# %%
df.loc[~df['Fence'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 5        6          50       RL         85.0    14115   Pave      IR1
# 14      15          20       RL          NaN    10920   Pave      IR1
# 15      16          45       RM         51.0     6120   Pave      Reg
# 19      20          20       RL         70.0     7560   Pave      Reg
# 21      22          45       RM         57.0     7449   Pave      Reg
# ...    ...         ...      ...          ...      ...    ...      ...
# 1436  1437          20       RL         60.0     9000   Pave      Reg
# 1438  1439          20       RM         90.0     7407   Pave      Reg
# 1448  1449          50       RL         70.0    11767   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 5            Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 14           Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 15           Lvl    AllPub    Corner       Gtl      BrkSide       Norm
# 19           Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 21           Bnk    AllPub    Inside       Gtl       IDOTRR       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1436         Lvl    AllPub       FR2       Gtl        NAmes       Norm
# 1438         Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 1448         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 5          Norm     1Fam     1.5Fin            5            5       1993
# 14         Norm     1Fam     1Story            6            5       1960
# 15         Norm     1Fam     1.5Unf            7            8       1929
# 19         Norm     1Fam     1Story            5            6       1958
# 21         Norm     1Fam     1.5Unf            7            7       1930
# ...         ...      ...        ...          ...          ...        ...
# 1436       Norm     1Fam     1Story            4            6       1971
# 1438       Norm     1Fam     1Story            6            7       1957
# 1448       Norm     1Fam     2Story            4            7       1910
# 1456       Norm     1Fam     1Story            6            6       1978
# 1457       Norm     1Fam     2Story            7            9       1941
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 5             1995     Gable  CompShg     VinylSd     VinylSd        NaN
# 14            1960       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 15            2001     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 19            1965       Hip  CompShg     BrkFace     Plywood        NaN
# 21            1950     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# ...            ...       ...      ...         ...         ...        ...
# 1436          1971     Gable  CompShg     HdBoard     HdBoard        NaN
# 1438          1996     Gable  CompShg     MetalSd     MetalSd        NaN
# 1448          2000     Gable  CompShg     MetalSd     HdBoard        NaN
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 5            0.0        TA        TA       Wood       Gd       TA
# 14         212.0        TA        TA     CBlock       TA       TA
# 15           0.0        TA        TA     BrkTil       TA       TA
# 19           0.0        TA        TA     CBlock       TA       TA
# 21           0.0        TA        TA      PConc       TA       TA
# ...          ...       ...       ...        ...      ...      ...
# 1436         0.0        TA        TA      PConc       TA       TA
# 1438         0.0        TA        TA     CBlock       TA       TA
# 1448         0.0        TA        TA     CBlock       Fa       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 5              No          GLQ         732          Unf           0
# 14             No          BLQ         733          Unf           0
# 15             No          Unf           0          Unf           0
# 19             No          LwQ         504          Unf           0
# 21             No          Unf           0          Unf           0
# ...           ...          ...         ...          ...         ...
# 1436           No          ALQ         616          Unf           0
# 1438           No          GLQ         600          Unf           0
# 1448           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 5            64          796    GasA        Ex          Y      SBrkr
# 14          520         1253    GasA        TA          Y      SBrkr
# 15          832          832    GasA        Ex          Y      FuseA
# 19          525         1029    GasA        TA          Y      SBrkr
# 21          637          637    GasA        Ex          Y      FuseF
# ...         ...          ...     ...       ...        ...        ...
# 1436        248          864    GasA        TA          Y      SBrkr
# 1438        312          912    GasA        TA          Y      FuseA
# 1448        560          560    GasA        Gd          N      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 5          796       566             0       1362             1             0
# 14        1253         0             0       1253             1             0
# 15         854         0             0        854             0             0
# 19        1339         0             0       1339             0             0
# 21        1108         0             0       1108             0             0
# ...        ...       ...           ...        ...           ...           ...
# 1436       864         0             0        864             0             0
# 1438      1236         0             0       1236             1             0
# 1448       796       550             0       1346             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 5            1         1             1             1          TA
# 14           1         1             2             1          TA
# 15           1         0             2             1          TA
# 19           1         0             3             1          TA
# 21           1         0             3             1          Gd
# ...        ...       ...           ...           ...         ...
# 1436         1         0             3             1          TA
# 1438         1         0             2             1          TA
# 1448         1         1             2             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 5                5        Typ           0         NaN     Attchd       1993.0
# 14               5        Typ           1          Fa     Attchd       1960.0
# 15               5        Typ           0         NaN     Detchd       1991.0
# 19               6       Min1           0         NaN     Attchd       1958.0
# 21               6        Typ           1          Gd     Attchd       1930.0
# ...            ...        ...         ...         ...        ...          ...
# 1436             5        Typ           0         NaN     Detchd       1974.0
# 1438             6        Typ           0         NaN     Attchd       1957.0
# 1448             6       Min2           0         NaN     Detchd       1950.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 5             Unf           2         480         TA         TA          Y
# 14            RFn           1         352         TA         TA          Y
# 15            Unf           2         576         TA         TA          Y
# 19            Unf           1         294         TA         TA          Y
# 21            Unf           1         280         TA         TA          N
# ...           ...         ...         ...        ...        ...        ...
# 1436          Unf           2         528         TA         TA          Y
# 1438          Unf           2         923         TA         TA          Y
# 1448          Unf           1         384         Fa         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 5             40           30              0        320            0
# 14             0          213            176          0            0
# 15            48          112              0          0            0
# 19             0            0              0          0            0
# 21             0            0            205          0            0
# ...          ...          ...            ...        ...          ...
# 1436           0            0              0          0            0
# 1438           0          158            158          0            0
# 1448         168           24              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
#
#       PoolArea  Fence  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# 5            0  MnPrv      700      10    2009       WD        Normal
# 14           0   GdWo        0       5    2008       WD        Normal
# 15           0  GdPrv        0       7    2007       WD        Normal
# 19           0  MnPrv        0       5    2009      COD       Abnorml
# 21           0  GdPrv        0       6    2007       WD        Normal
# ...        ...    ...      ...     ...     ...      ...           ...
# 1436         0   GdWo        0       5    2007       WD        Normal
# 1438         0  MnPrv        0       4    2010       WD        Normal
# 1448         0   GdWo        0       5    2007       WD        Normal
# 1456         0  MnPrv        0       2    2010       WD        Normal
# 1457         0  GdPrv     2500       5    2010       WD        Normal
#
#       SalePrice
# 5        143000
# 14       157000
# 15       132000
# 19       139000
# 21       139400
# ...         ...
# 1436     120500
# 1438     149700
# 1448     112000
# 1456     210000
# 1457     266500
#
# [281 rows x 78 columns]

# %%
df.loc[df['Fence'].isnull(), 'Fence'] = 'No Fence'

# %%
df.loc[df['Fence'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, Fence, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
df.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 115    116         160       FV         34.0     3230   Pave      Reg
# 173    174          20       RL         80.0    10197   Pave      IR1
# 1149  1150          70       RM         50.0     9000   Pave      Reg
# 369    370          20       RL          NaN     9830   Pave      IR1
# 49      50          20       RL         66.0     7742   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 115          Lvl    AllPub    Corner       Gtl      Somerst       Norm
# 173          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1149         Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 369          Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 49           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 115        Norm   TwnhsE     2Story            6            5       1999
# 173        Norm     1Fam     1Story            6            5       1961
# 1149       Norm     1Fam     2Story            7            9       1920
# 369        Norm     1Fam     1Story            5            7       1959
# 49         Norm     1Fam     1Story            5            7       1966
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 115           1999     Gable  CompShg     MetalSd     MetalSd    BrkFace
# 173           1961     Gable  CompShg     WdShing     Wd Shng     BrkCmn
# 1149          1988       Hip  CompShg     VinylSd     VinylSd        NaN
# 369           2006     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 49            1966     Gable  CompShg     HdBoard     HdBoard        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 115       1129.0        TA        TA      PConc       Gd       TA
# 173        491.0        TA        TA     CBlock       TA       TA
# 1149         0.0        TA        Gd      PConc       TA       TA
# 369          0.0        TA        Gd     CBlock       TA       TA
# 49           0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 115            No          GLQ         419          Unf           0
# 173            No          ALQ         288          Rec         374
# 1149           No          ALQ         624          Unf           0
# 369            No          ALQ          72          Rec         258
# 49             No          BLQ         763          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 115         310          729    GasA        Gd          Y      SBrkr
# 173         700         1362    GasA        TA          Y      SBrkr
# 1149         26          650    GasA        Ex          Y      SBrkr
# 369         733         1063    GasA        Ex          Y      SBrkr
# 49          192          955    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 115        729       729             0       1458             0             0
# 173       1362         0             0       1362             1             0
# 1149       832       650             0       1482             0             1
# 369       1287         0             0       1287             1             0
# 49         955         0             0        955             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 115          2         1             2             1          TA
# 173          1         1             3             1          TA
# 1149         1         0             3             1          TA
# 369          1         0             3             1          Gd
# 49           1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 115              5        Typ           1          Fa     Detchd       1999.0
# 173              6        Typ           1          TA     Attchd       1961.0
# 1149             7        Typ           0         NaN     Detchd       1930.0
# 369              7        Typ           1          Gd     Detchd       1997.0
# 49               6        Typ           0         NaN     Attchd       1966.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 115           Unf           2         440         TA         TA          Y
# 173           Unf           2         504         TA         TA          Y
# 1149          Unf           2         324         TA         TA          Y
# 369           Fin           2         576         TA         TA          Y
# 49            Unf           1         386         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 115            0           32              0          0            0
# 173            0           20              0          0            0
# 1149           0            0              0          0            0
# 369          364           17              0          0          182
# 49             0            0              0          0            0
#
#       PoolArea     Fence  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# 115          0  No Fence        0       6    2007       WD        Normal
# 173          0  No Fence        0       6    2008      COD        Normal
# 1149         0  No Fence        0       7    2009       WD        Normal
# 369          0  No Fence        0       3    2010       WD        Normal
# 49           0     MnPrv        0       1    2007       WD        Normal
#
#       SalePrice
# 115      176000
# 173      163000
# 1149     143000
# 369      162000
# 49       127000

# %% [markdown]
# MasVnrType: Masonry veneer type
# During the evaluation of the 'MasVnrType' column, it was noted that 'NaN' values indicate the absence of a masonry veneer type for the respective houses. Given this interpretation, it's crucial to retain this column to determine whether a dwelling has a masonry veneer type or not. To enhance clarity and consistency, the 'NaN' values should be replaced with 'No Masonry'

# %%
df['MasVnrType']
# Out:
# 0       BrkFace
# 1           NaN
# 2       BrkFace
# 3           NaN
# 4       BrkFace
#          ...
# 1455        NaN
# 1456      Stone
# 1457        NaN
# 1458        NaN
# 1459        NaN
# Name: MasVnrType, Length: 1460, dtype: object

# %%
df.loc[df['MasVnrType'].isnull(), 'MasVnrType'] = 'No Masonry'

# %%
df.loc[df['MasVnrType'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, Fence, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
df.head(10)['MasVnrType']
# Out:
# 0       BrkFace
# 1    No Masonry
# 2       BrkFace
# 3    No Masonry
# 4       BrkFace
# 5    No Masonry
# 6         Stone
# 7         Stone
# 8    No Masonry
# 9    No Masonry
# Name: MasVnrType, dtype: object

# %%
df['FireplaceQu']
# Out:
# 0       NaN
# 1        TA
# 2        TA
# 3        Gd
# 4        TA
#        ...
# 1455     TA
# 1456     TA
# 1457     Gd
# 1458    NaN
# 1459    NaN
# Name: FireplaceQu, Length: 1460, dtype: object

# %%
df.loc[df['FireplaceQu'].isnull(), 'FireplaceQu'] = 'No Fireplace'

# %%
df.loc[df['FireplaceQu'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, Fence, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %% [markdown]
# GarageType: Garage location | GarageFinish: Interior finish of the garage | GarageQual: Garage quality | GarageCond: Garage condition
# GarageArea: Size of garage in square feet
#
# In dwelling without a garage, the garage area value appears as 0 in the 'GarageArea' column. Therefore, it seems appropriate to fill the NaN values in the 'GarageType', 'GarageFinish', 'GarageQual', and 'GarageCond' columns with 'No Garage'. This step is important for consistently specifying the garage features of the houses.

# %%
df.loc[df['GarageArea']].head()
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 548  549          20       RM         49.0     8235   Pave      IR1
# 460  461          60       FV         75.0     8004   Pave      IR1
# 608  609          70       RL         78.0    12168   Pave      Reg
# 642  643          80       RL         75.0    13860   Pave      Reg
# 836  837          30       RM         90.0     8100   Pave      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 548         HLS    AllPub    Inside       Gtl      OldTown      Feedr
# 460         Lvl    AllPub    Inside       Gtl      Somerst       RRAn
# 608         HLS    AllPub    Inside       Mod      Crawfor       Norm
# 642         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 836         Lvl    AllPub    Inside       Gtl      OldTown       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 548       RRNn     1Fam     1Story            5            7       1955
# 460       Norm     1Fam     2Story            8            5       2009
# 608       Norm     1Fam     2Story            8            6       1934
# 642       Norm     1Fam       SLvl            8            7       1972
# 836       Norm     1Fam     1Story            5            6       1948
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  MasVnrType  \
# 548          1995     Gable  CompShg     MetalSd     MetalSd  No Masonry
# 460          2009     Gable  CompShg     VinylSd     VinylSd       Stone
# 608          1998     Gable  CompShg     BrkFace     Wd Sdng  No Masonry
# 642          1995     Gable  CompShg     Plywood     Wd Sdng  No Masonry
# 836          1973     Gable  CompShg     VinylSd     VinylSd  No Masonry
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 548         0.0        TA        Gd     CBlock       TA       TA           No
# 460       110.0        Gd        TA      PConc       Gd       TA           No
# 608         0.0        TA        TA      PConc       Gd       TA           Mn
# 642         0.0        Gd        TA     CBlock       Gd       TA           Gd
# 836         0.0        TA        TA     BrkTil       TA       TA           No
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 548          LwQ         180          Rec         645          0          825
# 460          GLQ         544          Unf           0        288          832
# 608          BLQ         428          Unf           0        537          965
# 642          GLQ        1410          Unf           0        542         1952
# 836          Rec         338          Unf           0       1221         1559
#
#     Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 548    GasA        TA          Y      SBrkr       825         0             0
# 460    GasA        Ex          Y      SBrkr       832      1103             0
# 608    GasA        TA          Y      SBrkr      1940      1254             0
# 642    GasA        Gd          Y      SBrkr      2000       704             0
# 836    GasA        Gd          Y      SBrkr      1559         0             0
#
#      GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 548        825             1             0         1         0             2
# 460       1935             1             0         2         1             3
# 608       3194             0             0         2         1             4
# 642       2704             1             0         2         1             4
# 836       1559             1             0         1         0             2
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 548             1          TA             4        Typ           0
# 460             1          TA             8        Typ           0
# 608             1          TA            10        Typ           2
# 642             1          Ex             9        Typ           3
# 836             1          TA             5       Min2           0
#
#       FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# 548  No Fireplace     Detchd       1963.0          RFn           2
# 460  No Fireplace    BuiltIn       2009.0          Fin           2
# 608            Gd    Basment       1934.0          Unf           2
# 642            TA     Attchd       1972.0          Fin           2
# 836  No Fireplace     Detchd       1948.0          Unf           2
#
#      GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 548         720         TA         TA          Y         140           50
# 460         552         TA         TA          Y           0          150
# 608         380         TA         TA          Y           0            0
# 642         538         TA         TA          Y         269          111
# 836         812         TA         TA          Y           0          116
#
#      EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea     Fence  MiscVal  \
# 548              0          0            0         0     MnPrv        0
# 460              0          0            0         0  No Fence        0
# 608              0          0            0         0  No Fence        0
# 642              0          0            0         0     MnPrv        0
# 836            230          0            0         0      GdWo        0
#
#      MoSold  YrSold SaleType SaleCondition  SalePrice
# 548       6    2008       WD        Normal     125000
# 460      12    2009      New       Partial     263435
# 608       9    2007       WD        Alloca     359100
# 642       7    2009       WD        Normal     345000
# 836       6    2007      COD        Normal     153500

# %%
df[df['GarageArea'] == 0].head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 39  40          90       RL         65.0     6040   Pave      Reg         Lvl
# 48  49         190       RM         33.0     4456   Pave      Reg         Lvl
# 78  79          90       RL         72.0    10778   Pave      Reg         Lvl
# 88  89          50  C (all)        105.0     8470   Pave      IR1         Lvl
# 89  90          20       RL         60.0     8070   Pave      Reg         Lvl
#
#    Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 39    AllPub    Inside       Gtl      Edwards       Norm       Norm   Duplex
# 48    AllPub    Inside       Gtl      OldTown       Norm       Norm   2fmCon
# 78    AllPub    Inside       Gtl       Sawyer       Norm       Norm   Duplex
# 88    AllPub    Corner       Gtl       IDOTRR      Feedr      Feedr     1Fam
# 89    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
#
#    HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 39     1Story            4            5       1955          1955     Gable
# 48     2Story            4            5       1920          2008     Gable
# 78     1Story            4            5       1968          1968       Hip
# 88     1.5Fin            3            2       1915          1982       Hip
# 89     1Story            4            5       1994          1995     Gable
#
#    RoofMatl Exterior1st Exterior2nd  MasVnrType  MasVnrArea ExterQual  \
# 39  CompShg     AsbShng     Plywood  No Masonry         0.0        TA
# 48  CompShg     MetalSd     MetalSd  No Masonry         0.0        TA
# 78  CompShg     HdBoard     HdBoard  No Masonry         0.0        TA
# 88  CompShg     Plywood     Plywood  No Masonry         0.0        Fa
# 89  CompShg     VinylSd     VinylSd  No Masonry         0.0        TA
#
#    ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 39        TA      PConc      NaN      NaN          NaN          NaN
# 48        TA     BrkTil       TA       TA           No          Unf
# 78        TA     CBlock       TA       TA           No          Unf
# 88        Fa     CBlock       TA       Fa           No          Unf
# 89        TA      PConc       Gd       TA           No          GLQ
#
#     BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 39           0          NaN           0          0            0    GasA
# 48           0          Unf           0        736          736    GasA
# 78           0          Unf           0       1768         1768    GasA
# 88           0          Unf           0       1013         1013    GasA
# 89         588          Unf           0        402          990    GasA
#
#    HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 39        TA          N      FuseP      1152         0             0
# 48        Gd          Y      SBrkr       736       716             0
# 78        TA          N      SBrkr      1768         0             0
# 88        TA          N      SBrkr      1013         0           513
# 89        Ex          Y      SBrkr       990         0             0
#
#     GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 39       1152             0             0         2         0             2
# 48       1452             0             0         2         0             2
# 78       1768             0             0         2         0             4
# 88       1526             0             0         1         0             2
# 89        990             1             0         1         0             3
#
#     KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 39             2          Fa             6        Typ           0
# 48             3          TA             8        Typ           0
# 78             2          TA             8        Typ           0
# 88             1          Fa             6        Typ           0
# 89             1          TA             5        Typ           0
#
#      FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 39  No Fireplace        NaN          NaN          NaN           0           0
# 48  No Fireplace        NaN          NaN          NaN           0           0
# 78  No Fireplace        NaN          NaN          NaN           0           0
# 88  No Fireplace        NaN          NaN          NaN           0           0
# 89  No Fireplace        NaN          NaN          NaN           0           0
#
#    GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 39        NaN        NaN          N           0            0              0
# 48        NaN        NaN          N           0            0            102
# 78        NaN        NaN          Y           0            0              0
# 88        NaN        NaN          N           0            0            156
# 89        NaN        NaN          Y           0            0              0
#
#     3SsnPorch  ScreenPorch  PoolArea     Fence  MiscVal  MoSold  YrSold  \
# 39          0            0         0  No Fence        0       6    2008
# 48          0            0         0  No Fence        0       6    2009
# 78          0            0         0  No Fence        0       4    2010
# 88          0            0         0     MnPrv        0      10    2009
# 89          0            0         0  No Fence        0       8    2007
#
#    SaleType SaleCondition  SalePrice
# 39       WD       AdjLand      82000
# 48      New       Partial     113000
# 78       WD        Normal     136500
# 88    ConLD       Abnorml      85000
# 89       WD        Normal     123600

# %%
# Replace missing values in 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond' columns with 'No Garage'
df[['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']] = df[['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']].fillna('No Garage')

# %%
df.loc[df[['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']].isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, Fence, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %% [markdown]
# BsmtExposure: Refers to walkout or garden level walls | BsmtFinType2: Rating of basement finished area (if multiple types) | BsmtQual: Evaluates the height of the basement | BsmtCond: Evaluates the general condition of the basement | BsmtFinType1: Rating of basement finished area
#
# When examining the columns 'BsmtExposure', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', and 'BsmtFinType1', it was observed that the 'NAN' values represent no basement. Therefore, it is appropriate to replace these columns with 'No Basement'.

# %%
df[['BsmtExposure', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtFinType1']].sample(10)
# Out:
#     BsmtExposure BsmtFinType2 BsmtQual BsmtCond BsmtFinType1
# 465           No          Unf       Gd       TA          Unf
# 594           No          Unf       Gd       TA          Unf
# 976           No          Unf       Gd       TA          Unf
# 819           Mn          Unf       Gd       TA          GLQ
# 147           No          Unf       Gd       TA          Unf
# 645           No          LwQ       TA       TA          ALQ
# 38            No          Unf       TA       TA          GLQ
# 48            No          Unf       TA       TA          Unf
# 677           No          Unf       TA       TA          Unf
# 120           Gd          Unf       TA       TA          ALQ

# %%
df[['BsmtExposure', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtFinType1']] = df[['BsmtExposure', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtFinType1']].fillna('No Basement')

# %%
df.loc[df[['BsmtExposure', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtFinType1']].isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, Fence, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
df.query('BsmtFinType2 == "No Basement"')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 17      18          90       RL         72.0    10791   Pave      Reg
# 39      40          90       RL         65.0     6040   Pave      Reg
# 90      91          20       RL         60.0     7200   Pave      Reg
# 102    103          90       RL         64.0     7018   Pave      Reg
# 156    157          20       RL         60.0     7200   Pave      Reg
# 182    183          20       RL         60.0     9060   Pave      Reg
# 259    260          20       RM         70.0    12702   Pave      Reg
# 332    333          20       RL         85.0    10655   Pave      IR1
# 342    343          90       RL          NaN     8544   Pave      Reg
# 362    363          85       RL         64.0     7301   Pave      Reg
# 371    372          50       RL         80.0    17120   Pave      Reg
# 392    393          20       RL          NaN     8339   Pave      IR1
# 520    521         190       RL         60.0    10800   Pave      Reg
# 532    533          20       RL         60.0     7200   Pave      Reg
# 533    534          20       RL         50.0     5000   Pave      Reg
# 553    554          20       RL         67.0     8777   Pave      Reg
# 646    647          20       RL         60.0     7200   Pave      Reg
# 705    706         190       RM         70.0     5600   Pave      Reg
# 736    737          90       RL         60.0     8544   Pave      Reg
# 749    750          50       RL         50.0     8405   Pave      Reg
# 778    779          90       RH         60.0     8400   Pave      Reg
# 868    869          60       RL          NaN    14762   Pave      IR2
# 894    895          90       RL         64.0     7018   Pave      Reg
# 897    898          90       RL         64.0     7018   Pave      Reg
# 984    985          90       RL         75.0    10125   Pave      Reg
# 1000  1001          20       RL         74.0    10206   Pave      Reg
# 1011  1012          90       RL         75.0     9825   Pave      Reg
# 1035  1036          20       RL          NaN    11500   Pave      IR1
# 1045  1046          20       RL          NaN    13680   Pave      IR1
# 1048  1049          20       RL        100.0    21750   Pave      Reg
# 1049  1050          20       RL         60.0    11100   Pave      Reg
# 1090  1091          90       RL         60.0     8544   Pave      Reg
# 1179  1180          20       RL         77.0     8335   Pave      Reg
# 1216  1217          90       RM         68.0     8930   Pave      Reg
# 1218  1219          50       RM         52.0     6240   Pave      Reg
# 1232  1233          90       RL         70.0     9842   Pave      Reg
# 1321  1322          20       RL          NaN     6627   Pave      IR1
# 1412  1413          90       RL         60.0     7200   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 17           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 39           Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 90           Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 102          Bnk    AllPub    Inside       Gtl      SawyerW       Norm
# 156          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 182          Lvl    AllPub    Inside       Gtl      Edwards     Artery
# 259          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 332          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 342          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 362          Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 371          Lvl    AllPub    Inside       Gtl      ClearCr      Feedr
# 392          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 520          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 532          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 533          Low    AllPub    Inside       Mod      BrkSide       Norm
# 553          Lvl    AllPub    Inside       Gtl      Edwards      Feedr
# 646          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 705          Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 736          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 749          Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 778          Lvl    AllPub    Inside       Gtl      SawyerW      Feedr
# 868          Lvl    AllPub    Corner       Gtl      Gilbert      Feedr
# 894          Bnk    AllPub    Inside       Gtl      SawyerW       Norm
# 897          Lvl    AllPub    Inside       Gtl      SawyerW      Feedr
# 984          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1000         Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 1011         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1035         Lvl    AllPub   CulDSac       Gtl      Edwards       Norm
# 1045         Lvl    AllPub   CulDSac       Gtl      Edwards       Norm
# 1048         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1049         Low    AllPub    Inside       Gtl      Edwards       Norm
# 1090         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1179         Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 1216         Lvl    AllPub    Inside       Gtl       Sawyer       RRAe
# 1218         Lvl    AllPub    Inside       Gtl      BrkSide       Norm
# 1232         Lvl    AllPub       FR2       Gtl        NAmes       Norm
# 1321         Lvl    AllPub    Corner       Gtl      BrkSide      Feedr
# 1412         Lvl    AllPub    Inside       Gtl        NAmes       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 17         Norm   Duplex     1Story            4            5       1967
# 39         Norm   Duplex     1Story            4            5       1955
# 90         Norm     1Fam     1Story            4            5       1950
# 102        Norm   Duplex     1Story            5            5       1979
# 156        Norm     1Fam     1Story            5            7       1950
# 182        Norm     1Fam     1Story            5            6       1957
# 259        Norm     1Fam     1Story            5            5       1956
# 332        Norm     1Fam     1Story            8            5       2003
# 342        Norm   Duplex     1Story            3            4       1949
# 362        Norm     1Fam     SFoyer            7            5       2003
# 371        Norm     1Fam     1.5Fin            4            4       1959
# 392        Norm     1Fam     1Story            5            7       1959
# 520        Norm   2fmCon     2Story            4            7       1900
# 532        Norm     1Fam     1Story            5            7       1955
# 533        Norm     1Fam     1Story            1            3       1946
# 553        Norm     1Fam     1Story            4            5       1949
# 646        Norm     1Fam     1Story            5            5       1950
# 705        Norm   2fmCon     2Story            4            5       1930
# 736        Norm   Duplex     1Story            3            4       1950
# 749        Norm     1Fam     1.5Fin            4            3       1945
# 778        Norm   Duplex     1Story            5            5       1977
# 868        Norm     1Fam     2Story            5            6       1948
# 894        Norm   Duplex     1Story            5            5       1979
# 897        Norm   Duplex     2Story            5            5       1979
# 984        Norm   Duplex     1.5Fin            5            5       1977
# 1000       Norm     1Fam     1Story            3            3       1952
# 1011       Norm   Duplex     1Story            5            5       1965
# 1035       Norm     1Fam     1Story            4            3       1957
# 1045       Norm     1Fam     1Story            3            5       1955
# 1048       Norm     1Fam     1Story            5            4       1960
# 1049       Norm     1Fam     1Story            4            7       1946
# 1090       Norm   Duplex     1Story            3            4       1950
# 1179       Norm     1Fam     1Story            5            5       1954
# 1216       Norm   Duplex     1.5Fin            6            5       1978
# 1218       Norm     1Fam     1.5Fin            4            5       1947
# 1232       Norm   Duplex     1Story            4            5       1962
# 1321       Norm     1Fam     1Story            3            6       1949
# 1412       Norm   Duplex     1Story            4            5       1949
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  MasVnrType  \
# 17            1967     Gable  CompShg     MetalSd     MetalSd  No Masonry
# 39            1955     Gable  CompShg     AsbShng     Plywood  No Masonry
# 90            1950     Gable  CompShg     BrkFace     Wd Sdng  No Masonry
# 102           1979     Gable  CompShg     HdBoard     HdBoard  No Masonry
# 156           1950       Hip  CompShg     Wd Sdng     Wd Sdng  No Masonry
# 182           2006       Hip  CompShg     Wd Sdng     Wd Sdng     BrkFace
# 259           1956     Gable  CompShg     BrkFace     BrkFace  No Masonry
# 332           2004     Gable  CompShg     VinylSd     VinylSd     BrkFace
# 342           1950     Gable  CompShg      Stucco      Stucco     BrkFace
# 362           2003     Gable  CompShg     HdBoard     HdBoard     BrkFace
# 371           1959     Gable  CompShg     WdShing     Plywood  No Masonry
# 392           1959     Gable  CompShg     MetalSd     MetalSd  No Masonry
# 520           2000     Gable  CompShg     MetalSd     MetalSd  No Masonry
# 532           2007     Gable  CompShg     VinylSd     VinylSd  No Masonry
# 533           1950     Gable  CompShg     VinylSd     VinylSd  No Masonry
# 553           2003     Gable  CompShg     VinylSd     VinylSd  No Masonry
# 646           1950       Hip  CompShg     MetalSd     MetalSd  No Masonry
# 705           1950       Hip  CompShg     VinylSd     Wd Shng  No Masonry
# 736           1950     Gable  CompShg      Stucco       Stone  No Masonry
# 749           1950     Gable  CompShg     WdShing     Wd Shng  No Masonry
# 778           1977     Gable  CompShg     Plywood     Plywood     BrkFace
# 868           1950     Gable  CompShg     Plywood     Plywood  No Masonry
# 894           1979     Gable  CompShg     Plywood     Plywood  No Masonry
# 897           1979     Gable  CompShg     Plywood     Plywood  No Masonry
# 984           1977     Gable  CompShg     Plywood     Plywood  No Masonry
# 1000          1952      Flat  Tar&Grv     BrkComm     Brk Cmn  No Masonry
# 1011          1965       Hip  CompShg     AsphShn     AsphShn  No Masonry
# 1035          1957     Gable  CompShg     Wd Sdng     Wd Sdng  No Masonry
# 1045          1955       Hip  CompShg     BrkFace     Wd Sdng  No Masonry
# 1048          2006       Hip  CompShg     HdBoard     HdBoard     BrkFace
# 1049          2006     Gable  CompShg     MetalSd     MetalSd  No Masonry
# 1090          1950     Gable  CompShg     BrkFace     BrkFace  No Masonry
# 1179          1954     Gable  CompShg     Wd Sdng     Wd Sdng  No Masonry
# 1216          1978     Gable  CompShg     VinylSd     VinylSd  No Masonry
# 1218          1950     Gable  CompShg     AsbShng     AsbShng  No Masonry
# 1232          1962     Gable  CompShg     HdBoard     HdBoard  No Masonry
# 1321          1950       Hip  CompShg     VinylSd     VinylSd  No Masonry
# 1412          1950     Gable  CompShg     BrkFace       Stone  No Masonry
#
#       MasVnrArea ExterQual ExterCond Foundation     BsmtQual     BsmtCond  \
# 17           0.0        TA        TA       Slab  No Basement  No Basement
# 39           0.0        TA        TA      PConc  No Basement  No Basement
# 90           0.0        TA        TA       Slab  No Basement  No Basement
# 102          0.0        TA        Fa       Slab  No Basement  No Basement
# 156          0.0        TA        TA     CBlock  No Basement  No Basement
# 182         98.0        TA        TA      PConc  No Basement  No Basement
# 259          0.0        TA        TA      PConc  No Basement  No Basement
# 332        296.0        Gd        TA      PConc           Gd           TA
# 342        340.0        TA        TA       Slab  No Basement  No Basement
# 362        500.0        Gd        TA       Slab  No Basement  No Basement
# 371          0.0        TA        TA     CBlock  No Basement  No Basement
# 392          0.0        TA        TA       Slab  No Basement  No Basement
# 520          0.0        TA        TA     BrkTil  No Basement  No Basement
# 532          0.0        TA        TA       Slab  No Basement  No Basement
# 533          0.0        Fa        Fa       Slab  No Basement  No Basement
# 553          0.0        TA        TA     CBlock  No Basement  No Basement
# 646          0.0        TA        TA     CBlock  No Basement  No Basement
# 705          0.0        Fa        Fa       Slab  No Basement  No Basement
# 736          0.0        TA        TA     CBlock  No Basement  No Basement
# 749          0.0        TA        TA       Slab  No Basement  No Basement
# 778        320.0        TA        TA       Slab  No Basement  No Basement
# 868          0.0        TA        TA       Slab  No Basement  No Basement
# 894          0.0        TA        TA       Slab  No Basement  No Basement
# 897          0.0        TA        TA       Slab  No Basement  No Basement
# 984          0.0        TA        TA     CBlock  No Basement  No Basement
# 1000         0.0        TA        TA       Slab  No Basement  No Basement
# 1011         0.0        TA        TA     CBlock  No Basement  No Basement
# 1035         0.0        TA        Gd       Slab  No Basement  No Basement
# 1045         0.0        TA        TA       Slab  No Basement  No Basement
# 1048        75.0        TA        Fa       Slab  No Basement  No Basement
# 1049         0.0        TA        TA     CBlock  No Basement  No Basement
# 1090         0.0        TA        TA       Slab  No Basement  No Basement
# 1179         0.0        TA        TA       Slab  No Basement  No Basement
# 1216         0.0        TA        TA       Slab  No Basement  No Basement
# 1218         0.0        TA        TA       Slab  No Basement  No Basement
# 1232         0.0        TA        TA       Slab  No Basement  No Basement
# 1321         0.0        TA        TA     CBlock  No Basement  No Basement
# 1412         0.0        TA        TA       Slab  No Basement  No Basement
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 17    No Basement  No Basement           0  No Basement           0
# 39    No Basement  No Basement           0  No Basement           0
# 90    No Basement  No Basement           0  No Basement           0
# 102   No Basement  No Basement           0  No Basement           0
# 156   No Basement  No Basement           0  No Basement           0
# 182   No Basement  No Basement           0  No Basement           0
# 259   No Basement  No Basement           0  No Basement           0
# 332            No          GLQ        1124  No Basement         479
# 342   No Basement  No Basement           0  No Basement           0
# 362   No Basement  No Basement           0  No Basement           0
# 371   No Basement  No Basement           0  No Basement           0
# 392   No Basement  No Basement           0  No Basement           0
# 520   No Basement  No Basement           0  No Basement           0
# 532   No Basement  No Basement           0  No Basement           0
# 533   No Basement  No Basement           0  No Basement           0
# 553   No Basement  No Basement           0  No Basement           0
# 646   No Basement  No Basement           0  No Basement           0
# 705   No Basement  No Basement           0  No Basement           0
# 736   No Basement  No Basement           0  No Basement           0
# 749   No Basement  No Basement           0  No Basement           0
# 778   No Basement  No Basement           0  No Basement           0
# 868   No Basement  No Basement           0  No Basement           0
# 894   No Basement  No Basement           0  No Basement           0
# 897   No Basement  No Basement           0  No Basement           0
# 984   No Basement  No Basement           0  No Basement           0
# 1000  No Basement  No Basement           0  No Basement           0
# 1011  No Basement  No Basement           0  No Basement           0
# 1035  No Basement  No Basement           0  No Basement           0
# 1045  No Basement  No Basement           0  No Basement           0
# 1048  No Basement  No Basement           0  No Basement           0
# 1049  No Basement  No Basement           0  No Basement           0
# 1090  No Basement  No Basement           0  No Basement           0
# 1179  No Basement  No Basement           0  No Basement           0
# 1216  No Basement  No Basement           0  No Basement           0
# 1218  No Basement  No Basement           0  No Basement           0
# 1232  No Basement  No Basement           0  No Basement           0
# 1321  No Basement  No Basement           0  No Basement           0
# 1412  No Basement  No Basement           0  No Basement           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 17            0            0    GasA        TA          Y      SBrkr
# 39            0            0    GasA        TA          N      FuseP
# 90            0            0    GasA        TA          Y      FuseA
# 102           0            0    GasA        TA          Y      SBrkr
# 156           0            0    GasA        TA          Y      FuseF
# 182           0            0    GasA        Ex          Y      SBrkr
# 259           0            0    GasA        Gd          Y      FuseA
# 332        1603         3206    GasA        Ex          Y      SBrkr
# 342           0            0    Wall        Fa          N      FuseA
# 362           0            0    GasA        Ex          Y      SBrkr
# 371           0            0    GasA        TA          Y      SBrkr
# 392           0            0    GasA        TA          Y      SBrkr
# 520           0            0    GasA        TA          N      FuseA
# 532           0            0    GasA        Ex          Y      SBrkr
# 533           0            0    GasA        Fa          N      FuseF
# 553           0            0    GasA        Ex          Y      SBrkr
# 646           0            0    GasA        Gd          Y      SBrkr
# 705           0            0    GasA        Fa          N      SBrkr
# 736           0            0    GasA        Gd          N      FuseF
# 749           0            0    Wall        TA          N      FuseF
# 778           0            0    GasA        TA          Y      SBrkr
# 868           0            0    GasA        Gd          Y      SBrkr
# 894           0            0    GasA        TA          Y      SBrkr
# 897           0            0    GasA        TA          Y      SBrkr
# 984           0            0    GasA        TA          Y      SBrkr
# 1000          0            0    GasW        Fa          N      FuseF
# 1011          0            0    GasA        TA          N      SBrkr
# 1035          0            0    GasA        Ex          N      SBrkr
# 1045          0            0    GasA        Ex          Y      FuseA
# 1048          0            0    GasA        TA          Y      SBrkr
# 1049          0            0    GasA        Ex          Y      SBrkr
# 1090          0            0    Wall        Fa          N      FuseA
# 1179          0            0    GasA        Gd          Y      SBrkr
# 1216          0            0    GasA        TA          Y      SBrkr
# 1218          0            0    GasA        Gd          N      SBrkr
# 1232          0            0    GasA        TA          Y      SBrkr
# 1321          0            0   Floor        TA          N      SBrkr
# 1412          0            0    Wall        Fa          N      FuseF
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 17        1296         0             0       1296             0             0
# 39        1152         0             0       1152             0             0
# 90        1040         0             0       1040             0             0
# 102       1535         0             0       1535             0             0
# 156       1040         0             0       1040             0             0
# 182       1340         0             0       1340             0             0
# 259        882         0             0        882             0             0
# 332       1629         0             0       1629             1             0
# 342       1040         0             0       1040             0             0
# 362        495      1427             0       1922             0             0
# 371       1120       468             0       1588             0             0
# 392        882         0             0        882             0             0
# 520        694       600             0       1294             0             0
# 532        827         0             0        827             0             0
# 533        334         0             0        334             0             0
# 553       1126         0             0       1126             0             0
# 646       1048         0             0       1048             0             0
# 705        372       720             0       1092             0             0
# 736       1040         0             0       1040             0             0
# 749       1088       441             0       1529             0             0
# 778       2020         0             0       2020             0             0
# 868       1547       720            53       2320             0             0
# 894       1535         0             0       1535             0             0
# 897       1120      1120             0       2240             0             0
# 984       1302       432             0       1734             0             0
# 1000       944         0             0        944             0             0
# 1011      1664         0             0       1664             0             0
# 1035       845         0             0        845             0             0
# 1045      1733         0             0       1733             0             0
# 1048      1771         0             0       1771             0             0
# 1049       930         0             0        930             0             0
# 1090      1040         0             0       1040             0             0
# 1179      1124         0             0       1124             0             0
# 1216      1318       584             0       1902             0             0
# 1218       672       240             0        912             0             0
# 1232      1224         0             0       1224             0             0
# 1321       720         0             0        720             0             0
# 1412      1040         0             0       1040             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 17           2         0             2             2          TA
# 39           2         0             2             2          Fa
# 90           1         0             2             1          TA
# 102          2         0             4             2          TA
# 156          1         0             2             1          TA
# 182          1         0             3             1          TA
# 259          1         0             2             1          TA
# 332          2         0             3             1          Gd
# 342          2         0             2             2          TA
# 362          3         0             4             1          Gd
# 371          2         0             4             1          TA
# 392          1         0             3             1          TA
# 520          2         0             3             2          TA
# 532          1         0             2             1          TA
# 533          1         0             1             1          Fa
# 553          2         0             2             1          Gd
# 646          1         0             3             1          TA
# 705          2         0             3             2          Fa
# 736          2         0             2             2          TA
# 749          2         0             4             1          TA
# 778          2         0             4             2          TA
# 868          2         0             2             1          TA
# 894          2         0             4             2          TA
# 897          2         0             6             2          TA
# 984          2         0             4             2          Gd
# 1000         1         0             2             1          Fa
# 1011         2         0             4             2          TA
# 1035         1         0             3             1          TA
# 1045         2         0             4             1          TA
# 1048         1         0             3             1          TA
# 1049         1         0             2             1          Gd
# 1090         2         0             2             2          TA
# 1179         1         0             3             1          TA
# 1216         2         0             4             2          TA
# 1218         1         0             2             1          TA
# 1232         2         0             2             2          TA
# 1321         1         0             2             1          TA
# 1412         2         0             2             2          TA
#
#       TotRmsAbvGrd Functional  Fireplaces   FireplaceQu GarageType  \
# 17               6        Typ           0  No Fireplace    CarPort
# 39               6        Typ           0  No Fireplace  No Garage
# 90               4        Typ           0  No Fireplace     Detchd
# 102              8        Typ           0  No Fireplace     Attchd
# 156              5        Typ           0  No Fireplace     Detchd
# 182              7        Typ           1            Gd     Attchd
# 259              4        Typ           0  No Fireplace     Detchd
# 332              7        Typ           1            Gd     Attchd
# 342              6        Typ           0  No Fireplace     Detchd
# 362              7        Typ           1            Ex    BuiltIn
# 371              7       Min2           1            Gd     Detchd
# 392              5        Typ           0  No Fireplace     Attchd
# 520              7        Typ           0  No Fireplace  No Garage
# 532              5        Mod           1            Po     Detchd
# 533              2        Typ           0  No Fireplace  No Garage
# 553              5        Typ           0  No Fireplace     Detchd
# 646              7       Min1           0  No Fireplace     Detchd
# 705              7        Mod           0  No Fireplace  No Garage
# 736              6        Typ           0  No Fireplace     Detchd
# 749              9        Mod           0  No Fireplace     Detchd
# 778             10        Typ           2            TA     Detchd
# 868              7        Typ           1            TA     Attchd
# 894              8        Typ           0  No Fireplace     Attchd
# 897             12        Typ           0  No Fireplace     Detchd
# 984              8        Typ           0  No Fireplace     Attchd
# 1000             4       Min1           0  No Fireplace     Detchd
# 1011             8        Typ           0  No Fireplace  No Garage
# 1035             5        Typ           0  No Fireplace     Detchd
# 1045             8       Min2           1            Gd     Attchd
# 1048             9       Min1           1            TA     Attchd
# 1049             6        Typ           0  No Fireplace     Detchd
# 1090             6        Typ           0  No Fireplace     Detchd
# 1179             5       Min2           1            Gd  No Garage
# 1216             8        Typ           0  No Fireplace     Attchd
# 1218             3        Typ           0  No Fireplace  No Garage
# 1232             6        Typ           0  No Fireplace    CarPort
# 1321             4        Typ           0  No Fireplace     Detchd
# 1412             6        Typ           0  No Fireplace     Detchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 17         1967.0          Unf           2         516         TA         TA
# 39            NaN    No Garage           0           0  No Garage  No Garage
# 90         1950.0          Unf           2         420         TA         TA
# 102        1979.0          Unf           2         410         TA         TA
# 156        1950.0          Unf           2         625         TA         TA
# 182        1957.0          RFn           1         252         TA         TA
# 259        1956.0          Unf           1         308         TA         TA
# 332        2003.0          RFn           3         880         TA         TA
# 342        1949.0          Unf           2         400         TA         TA
# 362        2003.0          RFn           2         672         TA         TA
# 371        1991.0          Fin           2         680         TA         TA
# 392        1959.0          RFn           1         294         TA         TA
# 520           NaN    No Garage           0           0  No Garage  No Garage
# 532        1967.0          Unf           1         392         TA         TA
# 533           NaN    No Garage           0           0  No Garage  No Garage
# 553        2002.0          Fin           2         520         TA         TA
# 646        1950.0          Unf           2         420         TA         TA
# 705           NaN    No Garage           0           0  No Garage  No Garage
# 736        1949.0          Unf           2         400         TA         TA
# 749        1945.0          Unf           1         240         TA         TA
# 778        1977.0          Unf           2         630         TA         TA
# 868        1979.0          Unf           2         672         TA         TA
# 894        1979.0          Unf           2         400         TA         TA
# 897        1979.0          Unf           2         528         TA         TA
# 984        1977.0          Unf           2         539         TA         TA
# 1000       1956.0          Unf           2         528         TA         Fa
# 1011          NaN    No Garage           0           0  No Garage  No Garage
# 1035       1957.0          Unf           1         290         TA         TA
# 1045       1955.0          Unf           2         452         TA         TA
# 1048       1960.0          Unf           2         336         TA         TA
# 1049       1946.0          Unf           1         308         TA         TA
# 1090       1987.0          Unf           2         400         TA         TA
# 1179          NaN    No Garage           0           0  No Garage  No Garage
# 1216       1978.0          Unf           2         539         TA         TA
# 1218          NaN    No Garage           0           0  No Garage  No Garage
# 1232       1962.0          Unf           2         462         TA         TA
# 1321       1955.0          Unf           1         287         TA         Fa
# 1412       1956.0          Unf           2         420         TA         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 17            Y           0            0              0          0
# 39            N           0            0              0          0
# 90            Y           0           29              0          0
# 102           Y           0            0              0          0
# 156           Y           0            0              0          0
# 182           Y         116            0              0        180
# 259           Y           0           45              0          0
# 332           Y           0            0              0          0
# 342           Y           0            0              0          0
# 362           Y           0            0            177          0
# 371           N           0           59              0          0
# 392           Y           0            0              0          0
# 520           N         220          114            210          0
# 532           Y           0            0              0          0
# 533           N           0            0              0          0
# 553           N           0           96              0          0
# 646           Y           0           27              0          0
# 705           N           0            0              0          0
# 736           Y           0            0              0          0
# 749           N          92            0            185          0
# 778           Y           0            0              0          0
# 868           P         120          144              0          0
# 894           Y           0            0              0          0
# 897           Y         154            0              0          0
# 984           Y           0            0              0          0
# 1000          Y           0            0              0          0
# 1011          Y           0            0              0          0
# 1035          N         186            0              0          0
# 1045          Y           0            0              0          0
# 1048          Y           0            0              0          0
# 1049          Y           0            0              0          0
# 1090          Y           0            0              0          0
# 1179          N           0           36            190          0
# 1216          Y           0            0              0          0
# 1218          N           0            0              0          0
# 1232          Y           0            0              0          0
# 1321          Y           0            0              0          0
# 1412          Y           0            0              0          0
#
#       ScreenPorch  PoolArea     Fence  MiscVal  MoSold  YrSold SaleType  \
# 17              0         0  No Fence      500      10    2006       WD
# 39              0         0  No Fence        0       6    2008       WD
# 90              0         0  No Fence        0       7    2006       WD
# 102             0         0  No Fence        0       6    2009       WD
# 156             0         0  No Fence        0       6    2006       WD
# 182             0         0     MnPrv        0       6    2007       WD
# 259             0         0  No Fence        0      12    2008       WD
# 332             0         0  No Fence        0      10    2009       WD
# 342             0         0  No Fence        0       5    2006       WD
# 362             0         0  No Fence        0       7    2009    ConLD
# 371             0         0  No Fence        0       7    2008       WD
# 392             0         0     MnPrv     1200       7    2007       WD
# 520             0         0  No Fence        0       8    2008       WD
# 532             0         0  No Fence        0       4    2010       WD
# 533             0         0  No Fence        0       1    2007       WD
# 553             0         0     MnPrv        0       5    2009       WD
# 646             0         0  No Fence        0       7    2008       WD
# 705             0         0  No Fence     3500       7    2010       WD
# 736             0         0  No Fence        0       7    2006       WD
# 749             0         0  No Fence        0       4    2009       WD
# 778             0         0  No Fence        0      10    2007       WD
# 868             0         0  No Fence        0       5    2006       WD
# 894             0         0  No Fence        0       6    2009       WD
# 897             0         0  No Fence        0       6    2009       WD
# 984             0         0  No Fence        0       8    2009      COD
# 1000            0         0  No Fence        0       7    2009       WD
# 1011            0         0  No Fence        0       5    2010       WD
# 1035            0         0  No Fence        0       1    2009       WD
# 1045            0         0  No Fence        0       6    2009       WD
# 1048            0         0     GdPrv        0      11    2009       WD
# 1049            0         0  No Fence        0       4    2010       WD
# 1090            0         0  No Fence        0       6    2009       WD
# 1179            0         0  No Fence        0       4    2006       WD
# 1216            0         0  No Fence        0       4    2010       WD
# 1218            0         0  No Fence        0       7    2006       WD
# 1232            0         0  No Fence        0       3    2007       WD
# 1321            0         0  No Fence        0       7    2008       WD
# 1412            0         0  No Fence        0       6    2009       WD
#
#      SaleCondition  SalePrice
# 17          Normal      90000
# 39         AdjLand      82000
# 90          Normal     109900
# 102         Alloca     118964
# 156         Normal     109500
# 182         Normal     120000
# 259         Normal      97000
# 332         Normal     284000
# 342         Normal      87500
# 362         Normal     198500
# 371         Normal     134432
# 392         Normal     106500
# 520         Normal     106250
# 532         Normal     107500
# 533         Normal      39300
# 553         Normal     108000
# 646         Normal      98300
# 705         Normal      55000
# 736         Normal      93500
# 749         Normal      98000
# 778         Normal     144000
# 868         Normal     169000
# 894         Alloca     118858
# 897         Alloca     142953
# 984         Normal     126000
# 1000        Normal      82000
# 1011        Normal     100000
# 1035        Normal      84000
# 1045        Normal     139600
# 1048        Normal     115000
# 1049       Abnorml      84900
# 1090        Normal      92900
# 1179        Normal      93000
# 1216        Normal     112000
# 1218        Normal      80500
# 1232        Normal     101800
# 1321        Normal      72500
# 1412        Normal      90000

# %% [markdown]
# Electrical: Electrical system
# It is observed that there is a missing value in the 'Electrical' column. Upon examining the observation containing the missing value, it appears appropriate to fill the missing value with the mode of all electrical observations.

# %%
df.loc[df['Electrical'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1379  1380          80       RL         73.0     9735   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1379         Lvl    AllPub    Inside       Gtl       Timber       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1379       Norm     1Fam       SLvl            5            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  MasVnrType  \
# 1379          2007     Gable  CompShg     VinylSd     VinylSd  No Masonry
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1379         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1379           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1379        384          384    GasA        Gd          Y        NaN
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1379       754       640             0       1394             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1379         2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces   FireplaceQu GarageType  \
# 1379             7        Typ           0  No Fireplace    BuiltIn
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 1379       2007.0          Fin           2         400         TA         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 1379          Y         100            0              0          0
#
#       ScreenPorch  PoolArea     Fence  MiscVal  MoSold  YrSold SaleType  \
# 1379            0         0  No Fence        0       5    2008       WD
#
#      SaleCondition  SalePrice
# 1379        Normal     167500

# %%
df.loc[df['Electrical'].isnull(), 'Electrical'] = df['Electrical'].mode()[0]

# %%
df['Electrical'].isnull().sum()
# Out:
# 0

# %%
df.iloc[[1379]]['Electrical']
# Out:
# 1379    SBrkr
# Name: Electrical, dtype: object

# %%
df[df.select_dtypes(include = ['object']).columns].isnull().sum()[df[df.select_dtypes(include = ['object']).columns].isnull().sum() > 0 ].sort_values(ascending = False)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# 2.2. Handling Missing Values in Numerical Features

# %%
numerical_columns = df.select_dtypes(include = ['number']).columns
numerical_columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
num_missing_values = df[numerical_columns].isnull().sum()
num_missing_values[num_missing_values > 0].sort_values(ascending = False)
# Out:
# LotFrontage    259
# GarageYrBlt     81
# MasVnrArea       8
# dtype: int64

# %% [markdown]
# LotFrontage: Linear feet of street connected to property
# It has been decided that filling the missing values in the 'LotFrontage' column with the median is more appropriate due to the presence of 88 outlier values.

# %%
df.loc[~df['LotFrontage'].isnull()].sort_values(by = 'LotFrontage')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 232    233         160       RM         21.0     1680   Pave      Reg
# 837    838         160       RM         21.0     1680   Pave      Reg
# 235    236         160       RM         21.0     1680   Pave      Reg
# 1029  1030         160       RM         21.0     1680   Pave      Reg
# 1038  1039         160       RM         21.0     1533   Pave      Reg
# ...    ...         ...      ...          ...      ...    ...      ...
# 231    232          60       RL        174.0    15138   Pave      IR1
# 197    198          75       RL        174.0    25419   Pave      Reg
# 1127  1128          20       RL        182.0    14572   Pave      IR3
# 934    935          20       RL        313.0    27650   Pave      IR2
# 1298  1299          60       RL        313.0    63887   Pave      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 232          Lvl    AllPub    Inside       Gtl       BrDale       Norm
# 837          Lvl    AllPub    Inside       Gtl       BrDale       Norm
# 235          Lvl    AllPub    Inside       Gtl       BrDale       Norm
# 1029         Lvl    AllPub    Inside       Gtl       BrDale       Norm
# 1038         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# ...          ...       ...       ...       ...          ...        ...
# 231          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 197          Lvl    AllPub    Corner       Gtl        NAmes     Artery
# 1127         Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 934          HLS    AllPub    Inside       Mod        NAmes       PosA
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 232        Norm    Twnhs     2Story            6            5       1972
# 837        Norm    Twnhs     2Story            6            5       1973
# 235        Norm   TwnhsE     2Story            6            3       1971
# 1029       Norm    Twnhs     2Story            6            7       1972
# 1038       Norm    Twnhs     2Story            4            6       1970
# ...         ...      ...        ...          ...          ...        ...
# 231        Norm     1Fam     2Story            8            5       1995
# 197        Norm     1Fam     2Story            8            4       1918
# 1127       Norm     1Fam     1Story            7            5       2004
# 934        Norm     1Fam     1Story            7            7       1960
# 1298       Norm     1Fam     2Story           10            5       2008
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  MasVnrType  \
# 232           1972     Gable  CompShg     HdBoard     HdBoard     BrkFace
# 837           1973     Gable  CompShg     HdBoard     HdBoard     BrkFace
# 235           1971     Gable  CompShg     HdBoard     HdBoard     BrkFace
# 1029          1972     Gable  CompShg     HdBoard     HdBoard     BrkFace
# 1038          2008     Gable  CompShg     CemntBd     CmentBd  No Masonry
# ...            ...       ...      ...         ...         ...         ...
# 231           1996     Gable  CompShg     VinylSd     VinylSd     BrkFace
# 197           1990     Gable  CompShg      Stucco      Stucco  No Masonry
# 1127          2004       Hip  CompShg     VinylSd     VinylSd  No Masonry
# 934           2007      Flat  Tar&Grv     Wd Sdng     Wd Sdng  No Masonry
# 1298          2008       Hip  ClyTile      Stucco      Stucco       Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 232        297.0        TA        TA     CBlock       TA       TA
# 837        158.0        TA        TA     CBlock       TA       TA
# 235        604.0        TA        TA     CBlock       TA       TA
# 1029       281.0        TA        TA     CBlock       TA       TA
# 1038         0.0        TA        TA     CBlock       TA       TA
# ...          ...       ...       ...        ...      ...      ...
# 231        506.0        Gd        TA      PConc       Gd       TA
# 197          0.0        Gd        Gd      PConc       TA       TA
# 1127         0.0        Gd        TA      PConc       Gd       TA
# 934          0.0        TA        TA     CBlock       Gd       TA
# 1298       796.0        Ex        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 232            No          Unf           0          Unf           0
# 837            No          BLQ         330          Unf           0
# 235            No          ALQ         358          Unf           0
# 1029           No          BLQ         317          Unf           0
# 1038           No          Unf           0          Unf           0
# ...           ...          ...         ...          ...         ...
# 231            No          GLQ         689          Unf           0
# 197            No          GLQ        1036          LwQ         184
# 1127           Av          GLQ        1300          Unf           0
# 934            Gd          GLQ         425          Unf           0
# 1298           Gd          GLQ        5644          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 232         483          483    GasA        TA          Y      SBrkr
# 837         153          483    GasA        TA          Y      SBrkr
# 235         125          483    GasA        TA          Y      SBrkr
# 1029        355          672    GasA        Gd          Y      SBrkr
# 1038        546          546    GasA        TA          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 231         773         1462    GasA        Ex          Y      SBrkr
# 197         140         1360    GasA        Gd          Y      SBrkr
# 1127        230         1530    GasA        Ex          Y      SBrkr
# 934         160          585    GasA        Ex          Y      SBrkr
# 1298        466         6110    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 232        483       504             0        987             0             0
# 837        483       504             0        987             1             0
# 235        483       504             0        987             0             0
# 1029       672       546             0       1218             0             1
# 1038       798       546             0       1344             0             0
# ...        ...       ...           ...        ...           ...           ...
# 231       1490      1304             0       2794             1             0
# 197       1360      1360           392       3112             1             1
# 1127      1530         0             0       1530             1             0
# 934       2069         0             0       2069             1             0
# 1298      4692       950             0       5642             2             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 232          1         1             2             1          TA
# 837          1         1             2             1          TA
# 235          1         1             2             1          TA
# 1029         1         1             3             1          TA
# 1038         1         1             3             1          TA
# ...        ...       ...           ...           ...         ...
# 231          2         1             4             1          Ex
# 197          2         0             4             1          Gd
# 1127         2         0             3             1          Gd
# 934          2         0             4             1          Gd
# 1298         2         1             3             1          Ex
#
#       TotRmsAbvGrd Functional  Fireplaces   FireplaceQu GarageType  \
# 232              5        Typ           1            Po     Attchd
# 837              5        Typ           0  No Fireplace     Detchd
# 235              5        Typ           0  No Fireplace     Detchd
# 1029             7        Typ           0  No Fireplace     Detchd
# 1038             6        Typ           1            TA  No Garage
# ...            ...        ...         ...           ...        ...
# 231              9        Typ           1            TA     Attchd
# 197              8        Typ           1            Ex     Detchd
# 1127             7        Typ           1            Gd     Attchd
# 934              9        Typ           1            Gd     Attchd
# 1298            12        Typ           3            Gd     Attchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 232        1972.0          Unf           1         288         TA         TA
# 837        1973.0          Unf           1         264         TA         TA
# 235        1971.0          Unf           1         264         TA         TA
# 1029       1972.0          Unf           1         264         TA         TA
# 1038          NaN    No Garage           0           0  No Garage  No Garage
# ...           ...          ...         ...         ...        ...        ...
# 231        1995.0          Fin           3         810         TA         TA
# 197        1918.0          Unf           2         795         TA         TA
# 1127       2004.0          Fin           3         630         TA         TA
# 934        1960.0          RFn           2         505         TA         TA
# 1298       2008.0          Fin           2        1418         TA         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 232           Y           0            0              0          0
# 837           Y           0            0              0          0
# 235           Y           0            0              0          0
# 1029          Y           0           28              0          0
# 1038          Y           0            0              0          0
# ...         ...         ...          ...            ...        ...
# 231           Y           0          146            202          0
# 197           Y           0           16            552          0
# 1127          Y         144           36              0          0
# 934           Y           0            0              0          0
# 1298          Y         214          292              0          0
#
#       ScreenPorch  PoolArea     Fence  MiscVal  MoSold  YrSold SaleType  \
# 232             0         0  No Fence        0       6    2006       WD
# 837             0         0  No Fence        0      11    2008       WD
# 235             0         0  No Fence        0       8    2008       WD
# 1029            0         0  No Fence        0       5    2006       WD
# 1038            0         0  No Fence        0       5    2009       WD
# ...           ...       ...       ...      ...     ...     ...      ...
# 231             0         0  No Fence        0       7    2009       WD
# 197             0       512     GdPrv        0       3    2006       WD
# 1127            0         0  No Fence        0      11    2007       WD
# 934             0         0  No Fence        0      11    2008       WD
# 1298            0       480  No Fence        0       1    2008      New
#
#      SaleCondition  SalePrice
# 232         Normal      94500
# 837         Normal     100000
# 235         Normal      89500
# 1029        Normal     118000
# 1038        Normal      97000
# ...            ...        ...
# 231         Normal     403000
# 197        Abnorml     235000
# 1127        Family     259000
# 934         Normal     242000
# 1298       Partial     160000
#
# [1201 rows x 78 columns]

# %%
df['LotFrontage'].describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
len(outliers(df, 'LotFrontage'))
# Out:
# 88

# %%
df['LotFrontage'].fillna(round(df['LotFrontage'].median()), inplace=True)

# %%
df['LotFrontage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# GarageYrBlt: Year garage was built
# When examining the median, outliers, and mean values of the GarageYrBlt' variable, filling the missing values with the mean value seems to be logical.

# %%
df.loc[df['GarageYrBlt'].isnull(), ['GarageYrBlt', 'YearBuilt', 'GarageType']].sort_values(by='GarageYrBlt')
# Out:
#       GarageYrBlt  YearBuilt GarageType
# 39            NaN       1955  No Garage
# 48            NaN       1920  No Garage
# 78            NaN       1968  No Garage
# 88            NaN       1915  No Garage
# 89            NaN       1994  No Garage
# ...           ...        ...        ...
# 1349          NaN       1872  No Garage
# 1407          NaN       1985  No Garage
# 1449          NaN       1970  No Garage
# 1450          NaN       1974  No Garage
# 1453          NaN       2006  No Garage
#
# [81 rows x 3 columns]

# %%
df['GarageYrBlt'].describe()
# Out:
# count    1379.000000
# mean     1978.506164
# std        24.689725
# min      1900.000000
# 25%      1961.000000
# 50%      1980.000000
# 75%      2002.000000
# max      2010.000000
# Name: GarageYrBlt, dtype: float64

# %%
len(outliers(df,'GarageYrBlt'))
# Out:
# 0

# %%
df['GarageYrBlt'].fillna(round(df['GarageYrBlt'].mean()), inplace=True)

# %%
df['GarageYrBlt'].isna().sum()
# Out:
# 0

# %% [markdown]
# MasVnrArea: Masonry veneer area in square feet

# %% [markdown]
# When examining the NaN values in the 'MasVnrArea' variable along with the 'MasVnrType' variable, it is understood that they represent 'no masonry'. Therefore, missing values should be filled with 0 (zero) to indicate the absence of masonry.

# %%
df[df['MasVnrArea'].isnull()][['MasVnrArea', 'MasVnrType']]
# Out:
#       MasVnrArea  MasVnrType
# 234          NaN  No Masonry
# 529          NaN  No Masonry
# 650          NaN  No Masonry
# 936          NaN  No Masonry
# 973          NaN  No Masonry
# 977          NaN  No Masonry
# 1243         NaN  No Masonry
# 1278         NaN  No Masonry

# %%
df['MasVnrArea'].describe()
# Out:
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %%
len(outliers(df,'MasVnrArea'))
# Out:
# 96

# %%
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)

# %%
df['MasVnrArea'].isna().sum()
# Out:
# 0

# %%
df.columns[df.isna().any()]
# Out:
# Index([], dtype='object')

# %%
InteractiveShell.ast_node_interactivity = "last"

# %% [markdown]
# 2. Handling Outliers

# %%
# num_col_boxplot is numerical columns list without 'Id'.
num_col_boxplot = df.select_dtypes(include=['number']).columns.tolist()
num_col_boxplot.remove('Id')
num_col_boxplot
# Out:
# ['MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
# matplotlib colors dictionary 
colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)
# Generated list of colors for future reference (for plots)
my_colors = [
    color for color,_ in colors.items()
]

# %%
# Find columns with outliers
outlier_list = []
for col in  num_col_boxplot:
    pass
    outliers1 = outliers(df, col)
    if len(outliers(df, col)) > 0:
        pass
        outlier_list.append(col)

# %%
num_plots = len(outlier_list)
num_rows = num_plots // 6 + (num_plots % 6 > 0)  # 6 columns for sub plots
num_cols = min(6, num_plots)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 3*num_rows))
for i, col in enumerate(outlier_list):
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]
    #data[[numerical_columns[i]]].plot(kind='box', ax=ax)
    sns.boxplot(df[[outlier_list[i]]], color = color_picker(my_colors),  width = 0.7, ax=ax)
    ax.set_title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Sales Price

# %% [markdown]
# SalePrice has 61 outliers values. All of the outliers are above upper boundary. There are approximetly 114 houses under 100000 USD and 5 houses under 50000 USD. However, those cheap houses were not inclueded in outliers. All of the outliers were checked and should stay in dataset.

# %%
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
outliers(df, 'SalePrice')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 11      12          60       RL         85.0    11924   Pave      IR1
# 53      54          20       RL         68.0    50271   Pave      IR1
# 58      59          60       RL         66.0    13682   Pave      IR2
# 112    113          60       RL         77.0     9965   Pave      Reg
# 151    152          20       RL        107.0    13891   Pave      Reg
# ...    ...         ...      ...          ...      ...    ...      ...
# 1268  1269          50       RL         69.0    14100   Pave      IR1
# 1353  1354          50       RL         56.0    14720   Pave      IR1
# 1373  1374          20       RL         69.0    11400   Pave      Reg
# 1388  1389          20       RL         42.0    14892   Pave      IR1
# 1437  1438          20       RL         96.0    12444   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 11           Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 53           Low    AllPub    Inside       Gtl      Veenker       Norm
# 58           HLS    AllPub   CulDSac       Gtl      StoneBr       Norm
# 112          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 151          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1268         Lvl    AllPub    Inside       Mod      Crawfor       Norm
# 1353         Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 1373         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1388         HLS    AllPub   CulDSac       Gtl      Gilbert       Norm
# 1437         Lvl    AllPub       FR2       Gtl      NridgHt       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 11         Norm     1Fam     2Story            9            5       2005
# 53         Norm     1Fam     1Story            9            5       1981
# 58         Norm     1Fam     2Story           10            5       2006
# 112        Norm     1Fam     2Story            7            5       2007
# 151        Norm     1Fam     1Story            8            5       2007
# ...         ...      ...        ...          ...          ...        ...
# 1268       Norm     1Fam     1.5Fin            8            9       1935
# 1353       Norm     1Fam     1.5Fin            8            5       1995
# 1373       Norm     1Fam     1Story           10            5       2001
# 1388       Norm     1Fam     1Story            9            5       2006
# 1437       Norm     1Fam     1Story            8            5       2008
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  MasVnrType  \
# 11            2006       Hip  CompShg     WdShing     Wd Shng       Stone
# 53            1987     Gable  WdShngl     WdShing     Wd Shng  No Masonry
# 58            2006       Hip  CompShg     VinylSd     VinylSd     BrkFace
# 112           2007     Gable  CompShg     VinylSd     VinylSd       Stone
# 151           2008       Hip  CompShg     VinylSd     VinylSd       Stone
# ...            ...       ...      ...         ...         ...         ...
# 1268          1997     Gable  CompShg      Stucco      Stucco     BrkFace
# 1353          1996       Hip  CompShg     VinylSd     VinylSd     BrkFace
# 1373          2002       Hip  CompShg     VinylSd     VinylSd     BrkFace
# 1388          2007     Gable  CompShg     VinylSd     VinylSd       Stone
# 1437          2008       Hip  CompShg     VinylSd     VinylSd       Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 11         286.0        Ex        TA      PConc       Ex       TA
# 53           0.0        Gd        TA     CBlock       Ex       TA
# 58        1031.0        Ex        TA      PConc       Ex       TA
# 112        220.0        Gd        TA      PConc       Ex       TA
# 151        436.0        Gd        TA      PConc       Ex       TA
# ...          ...       ...       ...        ...      ...      ...
# 1268       632.0        TA        Gd     CBlock       TA       TA
# 1353       579.0        Gd        TA      PConc       Gd       TA
# 1373       705.0        Ex        TA      PConc       Ex       TA
# 1388       160.0        Ex        TA      PConc       Ex       TA
# 1437       426.0        Ex        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 11             No          GLQ         998          Unf           0
# 53             Gd          GLQ        1810          Unf           0
# 58             Gd          Unf           0          Unf           0
# 112            Av          GLQ         984          Unf           0
# 151            Gd          GLQ        1400          Unf           0
# ...           ...          ...         ...          ...         ...
# 1268           Mn          Rec         192          Unf           0
# 1353           Av          GLQ         816          Unf           0
# 1373           Gd          GLQ        1282          Unf           0
# 1388           Gd          GLQ        1320          Unf           0
# 1437           Av          GLQ        1336          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 11          177         1175    GasA        Ex          Y      SBrkr
# 53           32         1842    GasA        Gd          Y      SBrkr
# 58         1410         1410    GasA        Ex          Y      SBrkr
# 112         280         1264    GasA        Ex          Y      SBrkr
# 151         310         1710    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1268        536          728    GasA        Ex          Y      SBrkr
# 1353       1217         2033    GasA        Ex          Y      SBrkr
# 1373       1351         2633    GasA        Ex          Y      SBrkr
# 1388        426         1746    GasA        Ex          Y      SBrkr
# 1437        596         1932    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 11        1182      1142             0       2324             1             0
# 53        1842         0             0       1842             2             0
# 58        1426      1519             0       2945             0             0
# 112       1282      1414             0       2696             1             0
# 151       1710         0             0       1710             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1268      1968      1479             0       3447             0             0
# 1353      2053      1185             0       3238             1             0
# 1373      2633         0             0       2633             1             0
# 1388      1746         0             0       1746             1             0
# 1437      1932         0             0       1932             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 11           3         0             4             1          Ex
# 53           0         1             0             1          Gd
# 58           3         1             3             1          Gd
# 112          2         1             4             1          Ex
# 151          2         0             2             1          Gd
# ...        ...       ...           ...           ...         ...
# 1268         3         1             4             1          Gd
# 1353         2         1             4             1          Gd
# 1373         2         1             2             1          Ex
# 1388         2         0             3             1          Ex
# 1437         2         0             2             1          Ex
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 11              11        Typ           2          Gd    BuiltIn       2005.0
# 53               5        Typ           1          Gd     Attchd       1981.0
# 58              10        Typ           1          Gd    BuiltIn       2006.0
# 112             10        Typ           1          Gd    BuiltIn       2007.0
# 151              6        Typ           1          Gd     Attchd       2007.0
# ...            ...        ...         ...         ...        ...          ...
# 1268            11        Typ           2          Gd    BuiltIn       1982.0
# 1353             9        Typ           1          Ex     Attchd       1996.0
# 1373             8        Typ           2          Gd     Attchd       2001.0
# 1388             7        Typ           2          Gd     Attchd       2006.0
# 1437             7        Typ           1          Gd     Attchd       2008.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 11            Fin           3         736         TA         TA          Y
# 53            Fin           3         894         TA         TA          Y
# 58            Fin           3         641         TA         TA          Y
# 112           Fin           3         792         TA         TA          Y
# 151           RFn           3         866         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1268          Unf           3        1014         TA         TA          Y
# 1353          Fin           3         666         TA         TA          Y
# 1373          RFn           3         804         TA         TA          Y
# 1388          Fin           3         758         TA         TA          Y
# 1437          Fin           3         774         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 11           147           21              0          0            0
# 53           857           72              0          0            0
# 58           192            0             37          0            0
# 112          120          184              0          0          168
# 151            0          102              0          0            0
# ...          ...          ...            ...        ...          ...
# 1268         314           12              0          0            0
# 1353         283           86              0          0            0
# 1373         314          140              0          0            0
# 1388         201           39              0          0            0
# 1437           0           66              0        304            0
#
#       PoolArea     Fence  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# 11           0  No Fence        0       7    2006      New       Partial
# 53           0  No Fence        0      11    2006       WD        Normal
# 58           0  No Fence        0      10    2006      New       Partial
# 112          0  No Fence        0      10    2007      New       Partial
# 151          0  No Fence        0       1    2008      New       Partial
# ...        ...       ...      ...     ...     ...      ...           ...
# 1268         0      GdWo        0       5    2008       WD        Normal
# 1353         0  No Fence        0       3    2010       WD        Normal
# 1373         0  No Fence        0       3    2007       WD        Normal
# 1388         0  No Fence        0      10    2009       WD        Normal
# 1437         0  No Fence        0      11    2008      New       Partial
#
#       SalePrice
# 11       345000
# 53       385000
# 58       438780
# 112      383970
# 151      372402
# ...         ...
# 1268     381000
# 1353     410000
# 1373     466500
# 1388     377500
# 1437     394617
#
# [61 rows x 78 columns]

# %%
len(outliers(df, 'SalePrice'))
# Out:
# 61

# %%
plt.figure(figsize=(10, 6))
plt.title('Sale Price Figure')
plt.grid(True)
sns.boxplot(df['SalePrice'], color = color_picker(my_colors), orient = 'h',  width = 0.5)
plt.show()

# %%
outliers(df,'SalePrice')[['SalePrice']]
# Out:
#       SalePrice
# 11       345000
# 53       385000
# 58       438780
# 112      383970
# 151      372402
# ...         ...
# 1268     381000
# 1353     410000
# 1373     466500
# 1388     377500
# 1437     394617
#
# [61 rows x 1 columns]

# %%
outliers(df, 'SalePrice')['SalePrice'].max()
# Out:
# 755000

# %%
df.query('SalePrice > 500000')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 178    179          20       RL         63.0    17423   Pave      IR1
# 440    441          20       RL        105.0    15431   Pave      Reg
# 691    692          60       RL        104.0    21535   Pave      IR1
# 769    770          60       RL         47.0    53504   Pave      IR2
# 803    804          60       RL        107.0    13891   Pave      Reg
# 898    899          20       RL        100.0    12919   Pave      IR1
# 1046  1047          60       RL         85.0    16056   Pave      IR1
# 1169  1170          60       RL        118.0    35760   Pave      IR1
# 1182  1183          60       RL        160.0    15623   Pave      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 178          Lvl    AllPub   CulDSac       Gtl      StoneBr       Norm
# 440          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 691          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 769          HLS    AllPub   CulDSac       Mod      StoneBr       Norm
# 803          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 898          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 1046         Lvl    AllPub    Inside       Gtl      StoneBr       Norm
# 1169         Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 1182         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 178        Norm     1Fam     1Story            9            5       2008
# 440        Norm     1Fam     1Story           10            5       2008
# 691        Norm     1Fam     2Story           10            6       1994
# 769        Norm     1Fam     2Story            8            5       2003
# 803        Norm     1Fam     2Story            9            5       2008
# 898        Norm     1Fam     1Story            9            5       2009
# 1046       Norm     1Fam     2Story            9            5       2005
# 1169       Norm     1Fam     2Story           10            5       1995
# 1182       Norm     1Fam     2Story           10            5       1996
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  MasVnrType  \
# 178           2009       Hip  CompShg     VinylSd     VinylSd       Stone
# 440           2008       Hip  CompShg     VinylSd     VinylSd       Stone
# 691           1995     Gable  WdShngl     HdBoard     HdBoard     BrkFace
# 769           2003       Hip  CompShg     CemntBd     Wd Shng     BrkFace
# 803           2009       Hip  CompShg     VinylSd     VinylSd       Stone
# 898           2010       Hip  CompShg     VinylSd     VinylSd       Stone
# 1046          2006       Hip  CompShg     CemntBd     CmentBd       Stone
# 1169          1996       Hip  CompShg     HdBoard     HdBoard     BrkFace
# 1182          1996       Hip  CompShg     Wd Sdng     ImStucc  No Masonry
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 178        748.0        Ex        TA      PConc       Ex       TA
# 440        200.0        Ex        TA      PConc       Ex       TA
# 691       1170.0        Ex        TA      PConc       Ex       TA
# 769        603.0        Ex        TA      PConc       Gd       TA
# 803        424.0        Ex        TA      PConc       Ex       TA
# 898        760.0        Ex        TA      PConc       Ex       TA
# 1046       208.0        Gd        TA      PConc       Ex       TA
# 1169      1378.0        Gd        Gd      PConc       Ex       TA
# 1182         0.0        Gd        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 178            No          GLQ        1904          Unf           0
# 440            Gd          GLQ        1767          ALQ         539
# 691            Gd          GLQ        1455          Unf           0
# 769            Gd          ALQ        1416          Unf           0
# 803            Gd          Unf           0          Unf           0
# 898            Gd          GLQ        2188          Unf           0
# 1046           Av          GLQ         240          Unf           0
# 1169           Gd          GLQ        1387          Unf           0
# 1182           Av          GLQ        2096          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 178         312         2216    GasA        Ex          Y      SBrkr
# 440         788         3094    GasA        Ex          Y      SBrkr
# 691         989         2444    GasA        Ex          Y      SBrkr
# 769         234         1650    GasA        Ex          Y      SBrkr
# 803        1734         1734    GasA        Ex          Y      SBrkr
# 898         142         2330    GasA        Ex          Y      SBrkr
# 1046       1752         1992    GasA        Ex          Y      SBrkr
# 1169        543         1930    GasA        Ex          Y      SBrkr
# 1182        300         2396    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 178       2234         0             0       2234             1             0
# 440       2402         0             0       2402             1             0
# 691       2444      1872             0       4316             0             1
# 769       1690      1589             0       3279             1             0
# 803       1734      1088             0       2822             0             0
# 898       2364         0             0       2364             1             0
# 1046      1992       876             0       2868             0             0
# 1169      1831      1796             0       3627             1             0
# 1182      2411      2065             0       4476             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 178          2         0             1             1          Ex
# 440          2         0             2             1          Ex
# 691          3         1             4             1          Ex
# 769          3         1             4             1          Ex
# 803          3         1             4             1          Ex
# 898          2         1             2             1          Ex
# 1046         3         1             4             1          Ex
# 1169         3         1             4             1          Gd
# 1182         3         1             4             1          Ex
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 178              9        Typ           1          Gd     Attchd       2009.0
# 440             10        Typ           2          Gd     Attchd       2008.0
# 691             10        Typ           2          Ex     Attchd       1994.0
# 769             12        Mod           1          Gd    BuiltIn       2003.0
# 803             12        Typ           1          Gd    BuiltIn       2009.0
# 898             11        Typ           2          Gd     Attchd       2009.0
# 1046            11        Typ           1          Gd    BuiltIn       2005.0
# 1169            10        Typ           1          TA     Attchd       1995.0
# 1182            10        Typ           2          TA     Attchd       1996.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 178           Fin           3        1166         TA         TA          Y
# 440           Fin           3         672         TA         TA          Y
# 691           Fin           3         832         TA         TA          Y
# 769           Fin           3         841         TA         TA          Y
# 803           RFn           3        1020         TA         TA          Y
# 898           Fin           3         820         TA         TA          Y
# 1046          Fin           3         716         TA         TA          Y
# 1169          Fin           3         807         TA         TA          Y
# 1182          Fin           3         813         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 178            0           60              0          0            0
# 440            0           72              0          0          170
# 691          382           50              0          0            0
# 769          503           36              0          0          210
# 803           52          170              0          0          192
# 898            0           67              0          0            0
# 1046         214          108              0          0            0
# 1169         361           76              0          0            0
# 1182         171           78              0          0            0
#
#       PoolArea     Fence  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# 178          0  No Fence        0       7    2009      New       Partial
# 440          0  No Fence        0       4    2009       WD        Normal
# 691          0  No Fence        0       1    2007       WD        Normal
# 769          0  No Fence        0       6    2010       WD        Normal
# 803          0  No Fence        0       1    2009      New       Partial
# 898          0  No Fence        0       3    2010      New       Partial
# 1046         0  No Fence        0       7    2006      New       Partial
# 1169         0  No Fence        0       7    2006       WD        Normal
# 1182       555     MnPrv        0       7    2007       WD       Abnorml
#
#       SalePrice
# 178      501837
# 440      555000
# 691      755000
# 769      538000
# 803      582933
# 898      611657
# 1046     556581
# 1169     625000
# 1182     745000

# %% [markdown]
# YearBuilt

# %% [markdown]
# YearBuilt column outlier records were examined and there were 6 outliers. They were all old dwellings. The mean of the YearBuilt column is 1971 and all of the outliers age are approximetly 100 years older than mean so these should be remove because these outliers would affect our model in a negative way.

# %%
outliers(df, 'YearBuilt')[['YearBuilt','SalePrice', 'Neighborhood', 'SaleCondition', 'LotArea', 'PoolArea', 'BedroomAbvGr', '1stFlrSF', '2ndFlrSF']]
# Out:
#       YearBuilt  SalePrice Neighborhood SaleCondition  LotArea  PoolArea  \
# 304        1880     295000      OldTown        Normal    18386         0
# 630        1880     124000      OldTown       Abnorml     9000         0
# 747        1880     265979      OldTown        Normal    11700         0
# 991        1882     168000      OldTown        Normal    17671         0
# 1132       1880     117500      OldTown        Normal     9900         0
# 1137       1875      94000       Sawyer        Normal     6342         0
# 1349       1872     122000      OldTown        Normal     5250         0
#
#       BedroomAbvGr  1stFlrSF  2ndFlrSF
# 304              3      1675      1818
# 630              3      1089       661
# 747              4      1320      1320
# 991              4       916       826
# 1132             5      1178      1032
# 1137             2       780       240
# 1349             4       938      1215

# %%
df['YearBuilt'].describe()
# Out:
# count    1460.000000
# mean     1971.267808
# std        30.202904
# min      1872.000000
# 25%      1954.000000
# 50%      1973.000000
# 75%      2000.000000
# max      2010.000000
# Name: YearBuilt, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.title('Year Built Plot')
plt.grid(True)
sns.boxplot(df['YearBuilt'], color = color_picker(my_colors), orient = 'h',  width = 0.5)
plt.show()

# %%
index_remove_yearbuilt = outliers(df, 'YearBuilt').index.tolist()

# %%
# The index_to_remove list created because add the all of the outliers that should remove.
index_to_remove = []

# %%
index_to_remove.append(index_remove_yearbuilt)
index_to_remove
# Out:
# [[304, 630, 747, 991, 1132, 1137, 1349]]

# %% [markdown]
# LotArea

# %% [markdown]
# Column Lot Area has been examined and 61 outliers have been detected. However, after visually inspecting the box plot, only the largest four have been decided to be removed.

# %%
outliers(df, 'LotArea')[['LotArea', 'YearBuilt','SalePrice', 'Neighborhood', 'SaleCondition', 'PoolArea', 'BedroomAbvGr', '1stFlrSF', '2ndFlrSF']]
# Out:
#       LotArea  YearBuilt  SalePrice Neighborhood SaleCondition  PoolArea  \
# 53      50271       1981     385000      Veenker        Normal         0
# 66      19900       1970     180000        NAmes        Normal         0
# 113     21000       1953     217000      Crawfor       Abnorml         0
# 120     21453       1969     180000      ClearCr        Normal         0
# 159     19378       2005     320000      Gilbert       Partial         0
# ...       ...        ...        ...          ...           ...       ...
# 1396    57200       1948     160000       Timber        Normal         0
# 1409    20544       1986     215000       NWAmes        Normal         0
# 1423    19690       1966     274970      Edwards        Alloca       738
# 1430    21930       2005     192140      Gilbert        Normal         0
# 1446    26142       1962     157900      Mitchel        Normal         0
#
#       BedroomAbvGr  1stFlrSF  2ndFlrSF
# 53               0      1842         0
# 66               3      2207         0
# 113              3      2259         0
# 120              1       988         0
# 159              4      1392      1070
# ...            ...       ...       ...
# 1396             3      1687         0
# 1409             3      1236       857
# 1423             4      1575       626
# 1430             4       734      1104
# 1446             3      1188         0
#
# [69 rows x 9 columns]

# %%
df['LotArea'].describe()
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.title('Lot Area Plot')
plt.grid(True)
sns.boxplot(df['LotArea'], color = color_picker(my_colors), orient = 'h',  width = 0.5)
plt.show()

# %%
outliers(df, 'LotArea').sort_values(by = 'LotArea')[-4:]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 706  707          20       RL         69.0   115149   Pave      IR2
# 249  250          50       RL         69.0   159000   Pave      IR2
# 335  336         190       RL         69.0   164660   Grvl      IR1
# 313  314          20       RL        150.0   215245   Pave      IR3
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 706         Low    AllPub   CulDSac       Sev      ClearCr       Norm
# 249         Low    AllPub   CulDSac       Sev      ClearCr       Norm
# 335         HLS    AllPub    Corner       Sev       Timber       Norm
# 313         Low    AllPub    Inside       Sev       Timber       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 706       Norm     1Fam     1Story            7            5       1971
# 249       Norm     1Fam     1.5Fin            6            7       1958
# 335       Norm   2fmCon     1.5Fin            5            6       1965
# 313       Norm     1Fam     1Story            7            5       1965
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  MasVnrType  \
# 706          2002     Gable  CompShg     Plywood     Plywood       Stone
# 249          2006     Gable  CompShg     Wd Sdng     HdBoard      BrkCmn
# 335          1965     Gable  CompShg     Plywood     Plywood  No Masonry
# 313          1965       Hip  CompShg     BrkFace     BrkFace  No Masonry
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 706       351.0        TA        TA     CBlock       Gd       TA           Gd
# 249       472.0        Gd        TA     CBlock       Gd       TA           Gd
# 335         0.0        TA        TA     CBlock       TA       TA           Gd
# 313         0.0        TA        TA     CBlock       Gd       TA           Gd
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 706          GLQ        1219          Unf           0        424         1643
# 249          Rec         697          Unf           0        747         1444
# 335          ALQ        1249          BLQ         147        103         1499
# 313          ALQ        1236          Rec         820         80         2136
#
#     Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 706    GasA        TA          Y      SBrkr      1824         0             0
# 249    GasA        Gd          Y      SBrkr      1444       700             0
# 335    GasA        Ex          Y      SBrkr      1619       167             0
# 313    GasW        TA          Y      SBrkr      2036         0             0
#
#      GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 706       1824             1             0         2         0             2
# 249       2144             0             1         2         0             4
# 335       1786             2             0         2         0             3
# 313       2036             2             0         2         0             3
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 706             1          Gd             5        Typ           2
# 249             1          Gd             7        Typ           2
# 335             1          TA             7        Typ           2
# 313             1          TA             8        Typ           2
#
#     FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 706          TA     Attchd       1971.0          Unf           2         739
# 249          TA     Attchd       1958.0          Fin           2         389
# 335          Gd     Attchd       1965.0          Fin           2         529
# 313          Gd     Attchd       1965.0          RFn           2         513
#
#     GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 706         TA         TA          Y         380           48              0
# 249         TA         TA          Y           0           98              0
# 335         TA         TA          Y         670            0              0
# 313         TA         TA          Y           0            0              0
#
#      3SsnPorch  ScreenPorch  PoolArea     Fence  MiscVal  MoSold  YrSold  \
# 706          0            0         0  No Fence        0       6    2007
# 249          0            0         0  No Fence      500       6    2007
# 335          0            0         0  No Fence      700       8    2008
# 313          0            0         0  No Fence        0       6    2009
#
#     SaleType SaleCondition  SalePrice
# 706       WD        Normal     302000
# 249       WD        Normal     277000
# 335       WD        Normal     228950
# 313       WD        Normal     375000

# %%
#outliers(data, 'LotArea').sort_values(by = 'LotArea')['LotArea'][-4:]
index_remove_LotArea = outliers(df, 'LotArea').sort_values(by = 'LotArea')[-4:].index.tolist()

# %%
index_to_remove.append(index_remove_LotArea)
index_to_remove
# Out:
# [[304, 630, 747, 991, 1132, 1137, 1349], [706, 249, 335, 313]]

# %% [markdown]
# GarageCars

# %% [markdown]
# After exemined the GarageCars column, no records will be removed

# %%
outliers(df, 'GarageCars')[['GarageCars', 'LotArea', 'YearBuilt','SalePrice', 'Neighborhood', 'SaleCondition', 'PoolArea', 'BedroomAbvGr', '1stFlrSF', '2ndFlrSF']]
# Out:
#       GarageCars  LotArea  YearBuilt  SalePrice Neighborhood SaleCondition  \
# 420            4     7060       1997     206300      Mitchel        Alloca
# 747            4    11700       1880     265979      OldTown        Normal
# 1190           4    32463       1961     168000      Mitchel        Normal
# 1340           4     8294       1971     123000        NAmes        Normal
# 1350           4    11643       1969     200000        NAmes        Normal
#
#       PoolArea  BedroomAbvGr  1stFlrSF  2ndFlrSF
# 420          0             2      1344         0
# 747          0             4      1320      1320
# 1190         0             3      1622         0
# 1340         0             3       872         0
# 1350         0             6      1338      1296

# %%
df['GarageCars'].describe()
# Out:
# count    1460.000000
# mean        1.767123
# std         0.747315
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: GarageCars, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.title('Garage Cars Plot')
plt.grid(True)
sns.boxplot(df['GarageCars'], color = color_picker(my_colors), orient = 'h',  width = 0.5)
plt.show()

# %% [markdown]
# GarageArea

# %% [markdown]
# After exemined the GarageArea column, no records will be removed.

# %%
outliers(df, 'GarageArea')[['GarageArea', 'GarageCars', 'LotArea', 'YearBuilt','SalePrice', 'Neighborhood', 'SaleCondition', 'PoolArea', 'BedroomAbvGr', '1stFlrSF', '2ndFlrSF']]
# Out:
#       GarageArea  GarageCars  LotArea  YearBuilt  SalePrice Neighborhood  \
# 178         1166           3    17423       2008     501837      StoneBr
# 224          968           3    13472       2003     386250      NridgHt
# 270         1053           3    10728       2006     266000      Somerst
# 317         1025           3     9000       2006     270000      Somerst
# 408          947           3    14154       2006     280000      NridgHt
# 581         1390           3    12704       2008     253293      NridgHt
# 664         1134           3    20896       2005     423000      Somerst
# 718          983           3    10542       1993     341000      NoRidge
# 803         1020           3    13891       2008     582933      NridgHt
# 825         1220           3    14803       2007     385000      NridgHt
# 1061        1248           3    18000       1935      81000       IDOTRR
# 1087        1043           3    10574       2005     252000      Somerst
# 1142        1052           3     9965       2006     424870      CollgCr
# 1184         995           3    35133       1963     186700       Timber
# 1190        1356           4    32463       1961     168000      Mitchel
# 1228        1052           3     8769       2008     367294      NridgHt
# 1241         954           3     9849       2007     248328      Somerst
# 1268        1014           3    14100       1935     381000      Crawfor
# 1298        1418           2    63887       2008     160000      Edwards
# 1350         968           4    11643       1969     200000        NAmes
# 1417        1069           3    16545       1998     340000      NoRidge
#
#      SaleCondition  PoolArea  BedroomAbvGr  1stFlrSF  2ndFlrSF
# 178        Partial         0             1      2234         0
# 224         Normal         0             3      2392         0
# 270        Partial         0             3      1095       844
# 317         Normal         0             3      1088       871
# 408        Partial         0             3      1071      1101
# 581        Partial         0             3      2042         0
# 664        Partial         0             1      2097         0
# 718         Normal         0             3      1325      1093
# 803        Partial         0             4      1734      1088
# 825        Partial         0             2      2084         0
# 1061        Normal         0             2       894         0
# 1087        Normal         0             3      1082       871
# 1142       Partial         0             4      1466      1362
# 1184        Normal         0             3      1572         0
# 1190        Normal         0             3      1622         0
# 1228       Partial         0             1      1702         0
# 1241       Partial         0             3      1689         0
# 1268        Normal         0             4      1968      1479
# 1298       Partial       480             3      4692       950
# 1350        Normal         0             6      1338      1296
# 1417        Normal         0             3      1310      1140

# %%
df['GarageArea'].describe()
# Out:
# count    1460.000000
# mean      472.980137
# std       213.804841
# min         0.000000
# 25%       334.500000
# 50%       480.000000
# 75%       576.000000
# max      1418.000000
# Name: GarageArea, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.title('Garage Area Plot')
plt.grid(True)
sns.boxplot(df['GarageArea'], color = color_picker(my_colors), orient = 'h',  width = 0.5)
plt.show()

# %% [markdown]
# index_to_remove

# %% [markdown]
# For now, only five columns were examined and the records to be removed have been added to a list. The other 27 numerical columns will be handled in Feature Engineering part

# %%
len(df)
# Out:
# 1460

# %%
new_list = []
for sublist in index_to_remove:  
    for item in sublist:      
        new_list.append(item)
new_list
# Out:
# [304, 630, 747, 991, 1132, 1137, 1349, 706, 249, 335, 313]

# %%
#index_to_remove[0]
df.drop(df.index[new_list], axis=0, inplace=True)

# %%
len(df)
# Out:
# 1449

# %%
df.to_csv("C:/Users/umitk/OneDrive/Documents/myspringboard/house_prediction/df_wrangling.csv", index=False)

# %% [markdown]
# 2. Conlusion

# %% [markdown]
# In this data wrangling phase, we made significant strides in preparing the dataset for modeling. We began by importing necessary libraries and defining functions for outlier detection and visualization. After loading the training dataset, we thoroughly inspected both categorical and numerical columns.
#
# For categorical columns, we identified and addressed missing values. Columns with a high percentage of missing values deemed irrelevant for modeling, such as 'PoolQC', 'MiscFeature', and 'Alley', were dropped. Missing values in other categorical columns were filled with appropriate values, ensuring completeness in categorical data.
#
# Moving on to numerical columns, we addressed missing values in three identified columns by imputing suitable values. We then investigated outliers in the top 5 numerical columns and removed 11 significant outliers, leaving the remaining outliers for potential feature engineering in later stages.
#
# Overall, the dataset has been cleaned, missing values have been addressed, and significant outliers have been mitigated. The data is now primed for further analysis and modeling, where we can delve deeper into feature engineering and model buiing.
